# %% [markdown]
# # Determining Most Frequent Collaborators for Songwriter Dataset

# %%
from collections import defaultdict
from functools import reduce
from itertools import combinations
import pickle

import pandas as pd 
import numpy as np

import dask.bag as db

from sklearn.metrics import pairwise_distances

# %% [markdown]
# ## Table of Contents
#
# 1. Functions
# 2. Importing Dataset
# 3. Computing Most Frequent Collaborators
# 4. Comparing Collaborators with Euclidean Model

# %% [markdown]
# ## 1. Functions

# %%
def import_and_strip_song_dataset_to_WID_CID(path):
    '''
    Imports song csv file at path and strips it to only 'WID' and 'CID' columns
    '''
    song_df = pd.read_csv(path, index_col=0)
    filtered_song_df = song_df[['WID', 
                               'CID']]
    return filtered_song_df

# %%
def mk_song_count_per_songwriter_dict(song_df_with_writer_and_composition_id):
    '''
    Creates a dictionary with writer id's as keys and each of the writers songs as values
    '''
    songwriter_corpus_dict = defaultdict(set)
    song_dict = song_df_with_writer_and_composition_id.to_dict(orient='index')
    for i in song_dict:
        songwriter_corpus_dict[song_dict[i]['WID']].add(song_dict[i]['CID'])
    songwriter_corpus_dict.default_factory = None
    return songwriter_corpus_dict

# %%
def remove_songwriters_w_less_than_4_songs(songwriter_corpus_dict):
    new_songwriter_dict = dict(map(lambda x: None if len(x.values()) < 4 else x, 
                                  songwriter_corpus_dict))
    return new_songwriter_dict

# %%
def get_intersection_of_writers_and_count_matches(songwriter_corpus_dict):
    '''
    Matches all songwriters in `songwriter_corpus_dict` with one another and determines
    what each pair has in common
    '''
    match_count_dict = {}
    combos = combinations(songwriter_corpus_dict.keys(), 2)
    for pair in combos:
        match_count_dict[pair] = len(songwriter_corpus_dict[pair[0]]\
                                     .intersection(songwriter_corpus_dict[pair[1]]))
    return match_count_dict

# %%
def remove_zero_match_counts(match_count_dict):
    for pair, value in list(match_count_dict.items()):
        if value == 0:
            del match_count_dict[pair]

# %% [markdown]
# ## 2. Importing Dataset

# %%
df = import_and_strip_song_dataset_to_WID_CID('../data/matched_tracks_w_writers_20190504.csv')

# %% [markdown]
# ## 3. Computing Most Frequent Collaborators

# %%
songwriter_songs_dict = mk_song_count_per_songwriter_dict(df)

# %%
# pruned_songwriter_songs_dict = remove_songwriters_w_less_than_4_songs(songwriter_songs_dict)

# %%
match_counts = get_intersection_of_writers_and_count_matches(songwriter_songs_dict)

# %%
remove_zero_match_counts(match_counts)

# %%
with open('../data/interim/match_counts.pkl', 'wb') as f:
    pkl.dump(match_counts, f)

# %%
len(match_counts)
# Out:
# 150508

# %%
np.mean(list(map(len, songwriter_songs_dict.values())))
# Out:
# 5.9075419614811056

# %% [markdown]
# ## 4. Comparing Collaborators with Euclidean Model

# %% [markdown]
# ### 4a. Loading Euclidean Based Songwriter Model

# %%
with open('../data/final_model_poc/top_12_writer_by_votes_euclidean_20190523.pkl', 'rb') as f:
    top_12s = pickle.load(f)

# %% [markdown]
# ### Loading Match Counts Dict

# %%
with open('../data/interim/match_counts.pkl', 'rb') as f:
    match_counts = pickle.load(f)

# %%
match_counts
# Out:
# {(7280, 7281): 76,
#  (347, 396712): 1,
#  (347, 104030): 1,
#  (347, 104031): 1,
#  (347, 104032): 1,
#  (347, 42183): 1,
#  (347, 42185): 1,
#  (347, 396729): 1,
#  (347, 105969): 1,
#  (347, 105971): 1,
#  (347, 105972): 1,
#  (347, 105973): 1,
#  (347, 74775): 1,
#  (347, 79900): 1,
#  (347, 199048): 1,
#  (347, 48744): 1,
#  (347, 41973): 2,
#  (347, 242364): 1,
#  (347, 66209): 1,
#  (347, 42292): 1,
#  (347, 242453): 1,
#  (347, 242455): 1,
#  (347, 21799): 1,
#  (347, 84537): 1,
#  (347, 70456): 1,
#  (347, 34921): 1,
#  (347, 27138): 3,
#  (347, 157277): 1,
#  (347, 287680): 1,
#  (347, 96803): 1,
#  (347, 27531): 1,
#  (347, 21084): 3,
#  (347, 9198): 1,
#  (347, 4677): 1,
#  (347, 15147): 1,
#  (347, 56435): 1,
#  (347, 27281): 2,
#  (347, 44115): 1,
#  (347, 5984): 1,
#  (347, 240479): 1,
#  (347, 10015): 59,
#  (347, 10025): 1,
#  (347, 43433): 1,
#  (347, 35798): 1,
#  (347, 56489): 1,
#  (347, 25016): 1,
#  (347, 47584): 1,
#  (347, 139019): 1,
#  (347, 12810): 1,
#  (347, 17116): 13,
#  (347, 8250): 1,
#  (347, 322128): 1,
#  (347, 69301): 1,
#  (347, 780): 1,
#  (347, 132953): 1,
#  (347, 132954): 1,
#  (347, 132955): 1,
#  (347, 132956): 1,
#  (347, 199589): 2,
#  (347, 442412): 2,
#  (347, 442413): 2,
#  (347, 442414): 1,
#  (347, 141408): 1,
#  (347, 551765): 1,
#  (347, 157748): 1,
#  (347, 178954): 2,
#  (347, 551749): 1,
#  (347, 12842): 1,
#  (347, 138691): 1,
#  (347, 310911): 1,
#  (347, 310960): 1,
#  (347, 246435): 1,
#  (347, 310999): 1,
#  (347, 15159): 1,
#  (347, 308987): 1,
#  (347, 308988): 1,
#  (347, 309050): 1,
#  (347, 27136): 3,
#  (347, 247360): 1,
#  (347, 339): 1,
#  (347, 218061): 1,
#  (347, 218062): 1,
#  (347, 68172): 1,
#  (347, 19703): 1,
#  (347, 132282): 1,
#  (347, 118694): 1,
#  (347, 55319): 4,
#  (347, 305139): 1,
#  (347, 305141): 1,
#  ...}

# %%
type((filter(lambda x: 110784 in x, match_counts)))
# Out:
# filter

# %%
[[number for number in tupl] for tupl in list(filter(lambda x: 110784 in x, match_counts))][:12]
# Out:
# [[110783, 110784],
#  [110784, 110785],
#  [110784, 14200],
#  [110784, 110788],
#  [110784, 27448],
#  [110784, 110786],
#  [110784, 110896],
#  [110784, 110916],
#  [110784, 110841]]

# %%
for i, v in pd.DataFrame(top_12s[110784]['top_matches']).iterrows():
    print(v[0])
# Out:
# 110784
# 110785
# 110783
# 27448
# 92607
# 167896
# 9007
# 379
# 14200
# 110916
# 695
# 38897

# %%
set(pd.DataFrame(top_12s[110784]['top_matches'])[0])
# Out:
# {379,
#  695,
#  9007,
#  14200,
#  27448,
#  38897,
#  92607,
#  110783,
#  110784,
#  110785,
#  110916,
#  167896}

# %%
set(pd.DataFrame(top_12s[110784]['top_matches']))
# Out:
# {0, 1}

# %% [markdown]
# ### Sorting Match Counts by Count

# %%
# https://stackoverflow.com/questions/20944483/python-3-sort-a-dict-by-its-values
match_counts_sorted = [(k, match_counts[k]) for k in sorted(match_counts, key=match_counts.get, reverse=True)]

# %% [markdown]
# ### Comparing Collabs vs Model Results

# %%
# https://stackoverflow.com/a/1388836
# https://stackoverflow.com/a/18072799

def check_freq_collabs_vs_model_results(freq_model : dict, distance_model : dict) -> dict:
    """
    Compares songwriter frequency counts vs distance based model results.
    
    Returns:
    - 'overlap' : int, the number of results per writer in common between the two
                     datasets
    - 'num_in_same_order' : int, the number of results per writer in the same ranked
                                 order between the two datasets
    
    Dependencies:
        - numpy
        - pandas
        - sklearn
    """
    results = {}
    for writer_id in distance_model:
        if writer_id in [number for tupl in list(filter(lambda x: writer_id in x, freq_model)) for number in tupl]:
            top_ids_freq_nested = [[number for number in tupl] for tupl in \
                               list(filter(lambda x: writer_id in x, freq_model))][:13]
            top_ids_freq_single_list = [number for tupl in list(filter(lambda x: writer_id in x, freq_model)) for number in tupl]
            top_ids_dist = pd.DataFrame(distance_model[writer_id]['top_matches'])\
                                            .rename(columns={0: 'WID', 1: 'freq'})

            results[writer_id] = {
                'overlap' : len(set(top_ids_freq_single_list).intersection(set(top_ids_dist['WID']))),
                'num_in_same_order' : len([i for i, j in zip(top_ids_dist, top_ids_freq_nested) if i in j])
            }
    return results

# %%
test_results = check_freq_collabs_vs_model_results(match_counts, top_12s)

# %%
len(test_results)
# Out:
# 29887

# %%
with open('../data/interim/freq_collab_model_comparison.pkl', 'wb') as f:
    pickle.dump(test_results, f)

# %%
test_results
# Out:
# {499782: {'overlap': 4, 'num_in_same_order': 0},
#  27407: {'overlap': 3, 'num_in_same_order': 0},
#  334033: {'overlap': 4, 'num_in_same_order': 0},
#  499753: {'overlap': 4, 'num_in_same_order': 0},
#  499755: {'overlap': 3, 'num_in_same_order': 0},
#  5011: {'overlap': 8, 'num_in_same_order': 0},
#  5014: {'overlap': 8, 'num_in_same_order': 0},
#  4985: {'overlap': 8, 'num_in_same_order': 0},
#  4986: {'overlap': 8, 'num_in_same_order': 0},
#  4987: {'overlap': 8, 'num_in_same_order': 0},
#  4988: {'overlap': 8, 'num_in_same_order': 0},
#  5010: {'overlap': 8, 'num_in_same_order': 0},
#  5015: {'overlap': 8, 'num_in_same_order': 0},
#  197387: {'overlap': 4, 'num_in_same_order': 0},
#  3145: {'overlap': 7, 'num_in_same_order': 0},
#  12804: {'overlap': 6, 'num_in_same_order': 0},
#  124370: {'overlap': 1, 'num_in_same_order': 0},
#  11787: {'overlap': 2, 'num_in_same_order': 0},
#  48751: {'overlap': 3, 'num_in_same_order': 0},
#  58542: {'overlap': 8, 'num_in_same_order': 0},
#  138577: {'overlap': 7, 'num_in_same_order': 0},
#  26215: {'overlap': 4, 'num_in_same_order': 0},
#  6497: {'overlap': 6, 'num_in_same_order': 0},
#  3725: {'overlap': 11, 'num_in_same_order': 0},
#  2586: {'overlap': 5, 'num_in_same_order': 0},
#  3835: {'overlap': 11, 'num_in_same_order': 0},
#  55319: {'overlap': 7, 'num_in_same_order': 0},
#  342318: {'overlap': 1, 'num_in_same_order': 0},
#  25641: {'overlap': 4, 'num_in_same_order': 0},
#  8756: {'overlap': 3, 'num_in_same_order': 0},
#  16554: {'overlap': 3, 'num_in_same_order': 0},
#  26371: {'overlap': 6, 'num_in_same_order': 0},
#  25375: {'overlap': 7, 'num_in_same_order': 0},
#  16909: {'overlap': 2, 'num_in_same_order': 0},
#  95565: {'overlap': 1, 'num_in_same_order': 0},
#  95566: {'overlap': 1, 'num_in_same_order': 0},
#  70472: {'overlap': 1, 'num_in_same_order': 0},
#  29622: {'overlap': 4, 'num_in_same_order': 0},
#  63156: {'overlap': 8, 'num_in_same_order': 0},
#  87373: {'overlap': 3, 'num_in_same_order': 0},
#  346204: {'overlap': 1, 'num_in_same_order': 0},
#  73557: {'overlap': 2, 'num_in_same_order': 0},
#  2612: {'overlap': 3, 'num_in_same_order': 0},
#  73671: {'overlap': 2, 'num_in_same_order': 0},
#  73672: {'overlap': 1, 'num_in_same_order': 0},
#  7417: {'overlap': 8, 'num_in_same_order': 0},
#  2574: {'overlap': 4, 'num_in_same_order': 0},
#  15372: {'overlap': 4, 'num_in_same_order': 0},
#  73807: {'overlap': 3, 'num_in_same_order': 0},
#  73808: {'overlap': 4, 'num_in_same_order': 0},
#  10117: {'overlap': 5, 'num_in_same_order': 0},
#  142917: {'overlap': 1, 'num_in_same_order': 0},
#  90233: {'overlap': 4, 'num_in_same_order': 0},
#  67839: {'overlap': 2, 'num_in_same_order': 0},
#  105470: {'overlap': 2, 'num_in_same_order': 0},
#  116530: {'overlap': 2, 'num_in_same_order': 0},
#  142919: {'overlap': 1, 'num_in_same_order': 0},
#  142923: {'overlap': 5, 'num_in_same_order': 0},
#  1076: {'overlap': 9, 'num_in_same_order': 0},
#  63392: {'overlap': 2, 'num_in_same_order': 0},
#  69279: {'overlap': 2, 'num_in_same_order': 0},
#  36920: {'overlap': 2, 'num_in_same_order': 0},
#  26352: {'overlap': 4, 'num_in_same_order': 0},
#  1128: {'overlap': 9, 'num_in_same_order': 0},
#  48737: {'overlap': 9, 'num_in_same_order': 0},
#  17755: {'overlap': 2, 'num_in_same_order': 0},
#  33371: {'overlap': 2, 'num_in_same_order': 0},
#  1010: {'overlap': 7, 'num_in_same_order': 0},
#  1129: {'overlap': 7, 'num_in_same_order': 0},
#  1130: {'overlap': 5, 'num_in_same_order': 0},
#  979: {'overlap': 8, 'num_in_same_order': 0},
#  19574: {'overlap': 4, 'num_in_same_order': 0},
#  9052: {'overlap': 4, 'num_in_same_order': 0},
#  17976: {'overlap': 2, 'num_in_same_order': 0},
#  48884: {'overlap': 3, 'num_in_same_order': 0},
#  73840: {'overlap': 1, 'num_in_same_order': 0},
#  6999: {'overlap': 6, 'num_in_same_order': 0},
#  32725: {'overlap': 3, 'num_in_same_order': 0},
#  120050: {'overlap': 5, 'num_in_same_order': 0},
#  120051: {'overlap': 5, 'num_in_same_order': 0},
#  120052: {'overlap': 5, 'num_in_same_order': 0},
#  402863: {'overlap': 2, 'num_in_same_order': 0},
#  32721: {'overlap': 5, 'num_in_same_order': 0},
#  32722: {'overlap': 4, 'num_in_same_order': 0},
#  9032: {'overlap': 4, 'num_in_same_order': 0},
#  561706: {'overlap': 2, 'num_in_same_order': 0},
#  561707: {'overlap': 2, 'num_in_same_order': 0},
#  15377: {'overlap': 5, 'num_in_same_order': 0},
#  42421: {'overlap': 7, 'num_in_same_order': 0},
#  10030: {'overlap': 6, 'num_in_same_order': 0},
#  42420: {'overlap': 7, 'num_in_same_order': 0},
#  207444: {'overlap': 3, 'num_in_same_order': 0},
#  15376: {'overlap': 4, 'num_in_same_order': 0},
#  4780: {'overlap': 7, 'num_in_same_order': 0},
#  168560: {'overlap': 6, 'num_in_same_order': 0},
#  125051: {'overlap': 4, 'num_in_same_order': 0},
#  294968: {'overlap': 2, 'num_in_same_order': 0},
#  294969: {'overlap': 4, 'num_in_same_order': 0},
#  3695: {'overlap': 8, 'num_in_same_order': 0},
#  16299: {'overlap': 8, 'num_in_same_order': 0},
#  16300: {'overlap': 6, 'num_in_same_order': 0},
#  16301: {'overlap': 6, 'num_in_same_order': 0},
#  16303: {'overlap': 8, 'num_in_same_order': 0},
#  140457: {'overlap': 9, 'num_in_same_order': 0},
#  446742: {'overlap': 8, 'num_in_same_order': 0},
#  175349: {'overlap': 6, 'num_in_same_order': 0},
#  175353: {'overlap': 5, 'num_in_same_order': 0},
#  175354: {'overlap': 6, 'num_in_same_order': 0},
#  175355: {'overlap': 7, 'num_in_same_order': 0},
#  108608: {'overlap': 8, 'num_in_same_order': 0},
#  16298: {'overlap': 4, 'num_in_same_order': 0},
#  34619: {'overlap': 6, 'num_in_same_order': 0},
#  2872: {'overlap': 4, 'num_in_same_order': 0},
#  34616: {'overlap': 4, 'num_in_same_order': 0},
#  5554: {'overlap': 8, 'num_in_same_order': 0},
#  78548: {'overlap': 6, 'num_in_same_order': 0},
#  124803: {'overlap': 3, 'num_in_same_order': 0},
#  217057: {'overlap': 3, 'num_in_same_order': 0},
#  1252: {'overlap': 6, 'num_in_same_order': 0},
#  217062: {'overlap': 3, 'num_in_same_order': 0},
#  22550: {'overlap': 7, 'num_in_same_order': 0},
#  43451: {'overlap': 2, 'num_in_same_order': 0},
#  63246: {'overlap': 4, 'num_in_same_order': 0},
#  29620: {'overlap': 2, 'num_in_same_order': 0},
#  23138: {'overlap': 7, 'num_in_same_order': 0},
#  11951: {'overlap': 4, 'num_in_same_order': 0},
#  19873: {'overlap': 5, 'num_in_same_order': 0},
#  10479: {'overlap': 8, 'num_in_same_order': 0},
#  3693: {'overlap': 7, 'num_in_same_order': 0},
#  202748: {'overlap': 3, 'num_in_same_order': 0},
#  107449: {'overlap': 1, 'num_in_same_order': 0},
#  202749: {'overlap': 3, 'num_in_same_order': 0},
#  4786: {'overlap': 1, 'num_in_same_order': 0},
#  352655: {'overlap': 1, 'num_in_same_order': 0},
#  190923: {'overlap': 1, 'num_in_same_order': 0},
#  33612: {'overlap': 4, 'num_in_same_order': 0},
#  310818: {'overlap': 5, 'num_in_same_order': 0},
#  33611: {'overlap': 4, 'num_in_same_order': 0},
#  59498: {'overlap': 4, 'num_in_same_order': 0},
#  63970: {'overlap': 6, 'num_in_same_order': 0},
#  138471: {'overlap': 3, 'num_in_same_order': 0},
#  14450: {'overlap': 7, 'num_in_same_order': 0},
#  75313: {'overlap': 7, 'num_in_same_order': 0},
#  35012: {'overlap': 2, 'num_in_same_order': 0},
#  6641: {'overlap': 5, 'num_in_same_order': 0},
#  15148: {'overlap': 6, 'num_in_same_order': 0},
#  73583: {'overlap': 4, 'num_in_same_order': 0},
#  151778: {'overlap': 2, 'num_in_same_order': 0},
#  151782: {'overlap': 1, 'num_in_same_order': 0},
#  2529: {'overlap': 7, 'num_in_same_order': 0},
#  4564: {'overlap': 5, 'num_in_same_order': 0},
#  15523: {'overlap': 6, 'num_in_same_order': 0},
#  4568: {'overlap': 8, 'num_in_same_order': 0},
#  1028: {'overlap': 7, 'num_in_same_order': 0},
#  16312: {'overlap': 6, 'num_in_same_order': 0},
#  19686: {'overlap': 9, 'num_in_same_order': 0},
#  15424: {'overlap': 4, 'num_in_same_order': 0},
#  1015: {'overlap': 6, 'num_in_same_order': 0},
#  45199: {'overlap': 2, 'num_in_same_order': 0},
#  94859: {'overlap': 3, 'num_in_same_order': 0},
#  7022: {'overlap': 7, 'num_in_same_order': 0},
#  43324: {'overlap': 4, 'num_in_same_order': 0},
#  465703: {'overlap': 3, 'num_in_same_order': 0},
#  465707: {'overlap': 1, 'num_in_same_order': 0},
#  465709: {'overlap': 2, 'num_in_same_order': 0},
#  43820: {'overlap': 8, 'num_in_same_order': 0},
#  43819: {'overlap': 8, 'num_in_same_order': 0},
#  3745: {'overlap': 10, 'num_in_same_order': 0},
#  71304: {'overlap': 4, 'num_in_same_order': 0},
#  19080: {'overlap': 7, 'num_in_same_order': 0},
#  47899: {'overlap': 3, 'num_in_same_order': 0},
#  396269: {'overlap': 2, 'num_in_same_order': 0},
#  7167: {'overlap': 7, 'num_in_same_order': 0},
#  7484: {'overlap': 8, 'num_in_same_order': 0},
#  3765: {'overlap': 2, 'num_in_same_order': 0},
#  3764: {'overlap': 3, 'num_in_same_order': 0},
#  9150: {'overlap': 3, 'num_in_same_order': 0},
#  12201: {'overlap': 2, 'num_in_same_order': 0},
#  45472: {'overlap': 2, 'num_in_same_order': 0},
#  45473: {'overlap': 2, 'num_in_same_order': 0},
#  112482: {'overlap': 3, 'num_in_same_order': 0},
#  3226: {'overlap': 3, 'num_in_same_order': 0},
#  39373: {'overlap': 3, 'num_in_same_order': 0},
#  107200: {'overlap': 2, 'num_in_same_order': 0},
#  1956: {'overlap': 3, 'num_in_same_order': 0},
#  9682: {'overlap': 4, 'num_in_same_order': 0},
#  20610: {'overlap': 7, 'num_in_same_order': 0},
#  20611: {'overlap': 2, 'num_in_same_order': 0},
#  26816: {'overlap': 1, 'num_in_same_order': 0},
#  26272: {'overlap': 2, 'num_in_same_order': 0},
#  14498: {'overlap': 4, 'num_in_same_order': 0},
#  59782: {'overlap': 2, 'num_in_same_order': 0},
#  83617: {'overlap': 1, 'num_in_same_order': 0},
#  349616: {'overlap': 2, 'num_in_same_order': 0},
#  3278: {'overlap': 1, 'num_in_same_order': 0},
#  193376: {'overlap': 5, 'num_in_same_order': 0},
#  235259: {'overlap': 5, 'num_in_same_order': 0},
#  552150: {'overlap': 6, 'num_in_same_order': 0},
#  369712: {'overlap': 9, 'num_in_same_order': 0},
#  552170: {'overlap': 5, 'num_in_same_order': 0},
#  91704: {'overlap': 5, 'num_in_same_order': 0},
#  91706: {'overlap': 4, 'num_in_same_order': 0},
#  10975: {'overlap': 5, 'num_in_same_order': 0},
#  18267: {'overlap': 5, 'num_in_same_order': 0},
#  3822: {'overlap': 6, 'num_in_same_order': 0},
#  18293: {'overlap': 6, 'num_in_same_order': 0},
#  2915: {'overlap': 6, 'num_in_same_order': 0},
#  98481: {'overlap': 5, 'num_in_same_order': 0},
#  15993: {'overlap': 3, 'num_in_same_order': 0},
#  1119: {'overlap': 4, 'num_in_same_order': 0},
#  7100: {'overlap': 2, 'num_in_same_order': 0},
#  7589: {'overlap': 5, 'num_in_same_order': 0},
#  7591: {'overlap': 4, 'num_in_same_order': 0},
#  96494: {'overlap': 3, 'num_in_same_order': 0},
#  78015: {'overlap': 4, 'num_in_same_order': 0},
#  96495: {'overlap': 2, 'num_in_same_order': 0},
#  78016: {'overlap': 2, 'num_in_same_order': 0},
#  33472: {'overlap': 8, 'num_in_same_order': 0},
#  19474: {'overlap': 2, 'num_in_same_order': 0},
#  517331: {'overlap': 4, 'num_in_same_order': 0},
#  517336: {'overlap': 2, 'num_in_same_order': 0},
#  517337: {'overlap': 2, 'num_in_same_order': 0},
#  517332: {'overlap': 3, 'num_in_same_order': 0},
#  517457: {'overlap': 1, 'num_in_same_order': 0},
#  31820: {'overlap': 5, 'num_in_same_order': 0},
#  121026: {'overlap': 4, 'num_in_same_order': 0},
#  121025: {'overlap': 4, 'num_in_same_order': 0},
#  121027: {'overlap': 4, 'num_in_same_order': 0},
#  121028: {'overlap': 4, 'num_in_same_order': 0},
#  271564: {'overlap': 4, 'num_in_same_order': 0},
#  96164: {'overlap': 4, 'num_in_same_order': 0},
#  271566: {'overlap': 4, 'num_in_same_order': 0},
#  271570: {'overlap': 4, 'num_in_same_order': 0},
#  271590: {'overlap': 2, 'num_in_same_order': 0},
#  271605: {'overlap': 3, 'num_in_same_order': 0},
#  69248: {'overlap': 1, 'num_in_same_order': 0},
#  670: {'overlap': 1, 'num_in_same_order': 0},
#  73772: {'overlap': 1, 'num_in_same_order': 0},
#  31293: {'overlap': 2, 'num_in_same_order': 0},
#  184: {'overlap': 10, 'num_in_same_order': 0},
#  56425: {'overlap': 5, 'num_in_same_order': 0},
#  12544: {'overlap': 9, 'num_in_same_order': 0},
#  1283: {'overlap': 6, 'num_in_same_order': 0},
#  56424: {'overlap': 6, 'num_in_same_order': 0},
#  56427: {'overlap': 6, 'num_in_same_order': 0},
#  65162: {'overlap': 3, 'num_in_same_order': 0},
#  65159: {'overlap': 1, 'num_in_same_order': 0},
#  65160: {'overlap': 2, 'num_in_same_order': 0},
#  65161: {'overlap': 5, 'num_in_same_order': 0},
#  39238: {'overlap': 8, 'num_in_same_order': 0},
#  22514: {'overlap': 3, 'num_in_same_order': 0},
#  43445: {'overlap': 6, 'num_in_same_order': 0},
#  28: {'overlap': 7, 'num_in_same_order': 0},
#  77282: {'overlap': 7, 'num_in_same_order': 0},
#  429000: {'overlap': 7, 'num_in_same_order': 0},
#  8450: {'overlap': 5, 'num_in_same_order': 0},
#  31559: {'overlap': 4, 'num_in_same_order': 0},
#  207538: {'overlap': 3, 'num_in_same_order': 0},
#  1924: {'overlap': 7, 'num_in_same_order': 0},
#  4824: {'overlap': 4, 'num_in_same_order': 0},
#  4828: {'overlap': 8, 'num_in_same_order': 0},
#  73719: {'overlap': 5, 'num_in_same_order': 0},
#  15607: {'overlap': 1, 'num_in_same_order': 0},
#  209489: {'overlap': 5, 'num_in_same_order': 0},
#  12545: {'overlap': 9, 'num_in_same_order': 0},
#  3397: {'overlap': 6, 'num_in_same_order': 0},
#  43823: {'overlap': 5, 'num_in_same_order': 0},
#  150503: {'overlap': 1, 'num_in_same_order': 0},
#  44093: {'overlap': 9, 'num_in_same_order': 0},
#  29125: {'overlap': 3, 'num_in_same_order': 0},
#  92278: {'overlap': 2, 'num_in_same_order': 0},
#  160419: {'overlap': 5, 'num_in_same_order': 0},
#  160420: {'overlap': 5, 'num_in_same_order': 0},
#  160421: {'overlap': 4, 'num_in_same_order': 0},
#  160425: {'overlap': 5, 'num_in_same_order': 0},
#  39071: {'overlap': 4, 'num_in_same_order': 0},
#  20040: {'overlap': 1, 'num_in_same_order': 0},
#  15672: {'overlap': 7, 'num_in_same_order': 0},
#  3453: {'overlap': 7, 'num_in_same_order': 0},
#  20612: {'overlap': 6, 'num_in_same_order': 0},
#  61213: {'overlap': 3, 'num_in_same_order': 0},
#  11510: {'overlap': 6, 'num_in_same_order': 0},
#  27139: {'overlap': 3, 'num_in_same_order': 0},
#  15373: {'overlap': 4, 'num_in_same_order': 0},
#  15374: {'overlap': 5, 'num_in_same_order': 0},
#  227089: {'overlap': 3, 'num_in_same_order': 0},
#  247320: {'overlap': 3, 'num_in_same_order': 0},
#  247319: {'overlap': 1, 'num_in_same_order': 0},
#  15375: {'overlap': 7, 'num_in_same_order': 0},
#  64977: {'overlap': 2, 'num_in_same_order': 0},
#  148331: {'overlap': 2, 'num_in_same_order': 0},
#  41040: {'overlap': 3, 'num_in_same_order': 0},
#  64978: {'overlap': 2, 'num_in_same_order': 0},
#  161539: {'overlap': 3, 'num_in_same_order': 0},
#  77876: {'overlap': 1, 'num_in_same_order': 0},
#  212502: {'overlap': 3, 'num_in_same_order': 0},
#  435957: {'overlap': 2, 'num_in_same_order': 0},
#  2968: {'overlap': 3, 'num_in_same_order': 0},
#  2969: {'overlap': 3, 'num_in_same_order': 0},
#  137649: {'overlap': 6, 'num_in_same_order': 0},
#  137641: {'overlap': 5, 'num_in_same_order': 0},
#  137642: {'overlap': 7, 'num_in_same_order': 0},
#  137643: {'overlap': 6, 'num_in_same_order': 0},
#  137645: {'overlap': 6, 'num_in_same_order': 0},
#  192: {'overlap': 4, 'num_in_same_order': 0},
#  30749: {'overlap': 4, 'num_in_same_order': 0},
#  34136: {'overlap': 2, 'num_in_same_order': 0},
#  122650: {'overlap': 5, 'num_in_same_order': 0},
#  81914: {'overlap': 5, 'num_in_same_order': 0},
#  122648: {'overlap': 3, 'num_in_same_order': 0},
#  122651: {'overlap': 3, 'num_in_same_order': 0},
#  122654: {'overlap': 5, 'num_in_same_order': 0},
#  1261: {'overlap': 5, 'num_in_same_order': 0},
#  89958: {'overlap': 3, 'num_in_same_order': 0},
#  23763: {'overlap': 2, 'num_in_same_order': 0},
#  185631: {'overlap': 3, 'num_in_same_order': 0},
#  170298: {'overlap': 2, 'num_in_same_order': 0},
#  185636: {'overlap': 1, 'num_in_same_order': 0},
#  35069: {'overlap': 1, 'num_in_same_order': 0},
#  35176: {'overlap': 1, 'num_in_same_order': 0},
#  35177: {'overlap': 1, 'num_in_same_order': 0},
#  35178: {'overlap': 1, 'num_in_same_order': 0},
#  35174: {'overlap': 2, 'num_in_same_order': 0},
#  103404: {'overlap': 2, 'num_in_same_order': 0},
#  159907: {'overlap': 2, 'num_in_same_order': 0},
#  17311: {'overlap': 1, 'num_in_same_order': 0},
#  39458: {'overlap': 5, 'num_in_same_order': 0},
#  6109: {'overlap': 5, 'num_in_same_order': 0},
#  39484: {'overlap': 5, 'num_in_same_order': 0},
#  95381: {'overlap': 5, 'num_in_same_order': 0},
#  177644: {'overlap': 5, 'num_in_same_order': 0},
#  340581: {'overlap': 2, 'num_in_same_order': 0},
#  1646: {'overlap': 4, 'num_in_same_order': 0},
#  1645: {'overlap': 6, 'num_in_same_order': 0},
#  45582: {'overlap': 1, 'num_in_same_order': 0},
#  45581: {'overlap': 1, 'num_in_same_order': 0},
#  69421: {'overlap': 2, 'num_in_same_order': 0},
#  69320: {'overlap': 3, 'num_in_same_order': 0},
#  69318: {'overlap': 3, 'num_in_same_order': 0},
#  48775: {'overlap': 8, 'num_in_same_order': 0},
#  1637: {'overlap': 5, 'num_in_same_order': 0},
#  10025: {'overlap': 10, 'num_in_same_order': 0},
#  10013: {'overlap': 12, 'num_in_same_order': 0},
#  270134: {'overlap': 9, 'num_in_same_order': 0},
#  10022: {'overlap': 9, 'num_in_same_order': 0},
#  10023: {'overlap': 10, 'num_in_same_order': 0},
#  23238: {'overlap': 8, 'num_in_same_order': 0},
#  23239: {'overlap': 6, 'num_in_same_order': 0},
#  23245: {'overlap': 9, 'num_in_same_order': 0},
#  4949: {'overlap': 7, 'num_in_same_order': 0},
#  25827: {'overlap': 7, 'num_in_same_order': 0},
#  25843: {'overlap': 7, 'num_in_same_order': 0},
#  25832: {'overlap': 7, 'num_in_same_order': 0},
#  25838: {'overlap': 7, 'num_in_same_order': 0},
#  27593: {'overlap': 6, 'num_in_same_order': 0},
#  38530: {'overlap': 1, 'num_in_same_order': 0},
#  347965: {'overlap': 1, 'num_in_same_order': 0},
#  3351: {'overlap': 3, 'num_in_same_order': 0},
#  1783: {'overlap': 3, 'num_in_same_order': 0},
#  69: {'overlap': 2, 'num_in_same_order': 0},
#  349798: {'overlap': 2, 'num_in_same_order': 0},
#  57680: {'overlap': 2, 'num_in_same_order': 0},
#  121890: {'overlap': 1, 'num_in_same_order': 0},
#  59748: {'overlap': 2, 'num_in_same_order': 0},
#  340618: {'overlap': 2, 'num_in_same_order': 0},
#  14761: {'overlap': 5, 'num_in_same_order': 0},
#  12797: {'overlap': 2, 'num_in_same_order': 0},
#  14536: {'overlap': 1, 'num_in_same_order': 0},
#  42618: {'overlap': 3, 'num_in_same_order': 0},
#  196138: {'overlap': 1, 'num_in_same_order': 0},
#  15814: {'overlap': 2, 'num_in_same_order': 0},
#  61498: {'overlap': 2, 'num_in_same_order': 0},
#  48146: {'overlap': 1, 'num_in_same_order': 0},
#  17678: {'overlap': 2, 'num_in_same_order': 0},
#  53986: {'overlap': 4, 'num_in_same_order': 0},
#  53991: {'overlap': 3, 'num_in_same_order': 0},
#  54014: {'overlap': 2, 'num_in_same_order': 0},
#  9965: {'overlap': 1, 'num_in_same_order': 0},
#  55317: {'overlap': 2, 'num_in_same_order': 0},
#  9963: {'overlap': 2, 'num_in_same_order': 0},
#  74326: {'overlap': 3, 'num_in_same_order': 0},
#  443232: {'overlap': 3, 'num_in_same_order': 0},
#  443246: {'overlap': 2, 'num_in_same_order': 0},
#  56235: {'overlap': 9, 'num_in_same_order': 0},
#  56253: {'overlap': 8, 'num_in_same_order': 0},
#  56274: {'overlap': 5, 'num_in_same_order': 0},
#  56242: {'overlap': 7, 'num_in_same_order': 0},
#  56275: {'overlap': 7, 'num_in_same_order': 0},
#  73589: {'overlap': 7, 'num_in_same_order': 0},
#  33970: {'overlap': 7, 'num_in_same_order': 0},
#  56237: {'overlap': 8, 'num_in_same_order': 0},
#  42195: {'overlap': 5, 'num_in_same_order': 0},
#  33971: {'overlap': 6, 'num_in_same_order': 0},
#  9864: {'overlap': 8, 'num_in_same_order': 0},
#  33969: {'overlap': 5, 'num_in_same_order': 0},
#  40379: {'overlap': 3, 'num_in_same_order': 0},
#  177434: {'overlap': 3, 'num_in_same_order': 0},
#  68: {'overlap': 2, 'num_in_same_order': 0},
#  15737: {'overlap': 2, 'num_in_same_order': 0},
#  7179: {'overlap': 2, 'num_in_same_order': 0},
#  27836: {'overlap': 3, 'num_in_same_order': 0},
#  18114: {'overlap': 6, 'num_in_same_order': 0},
#  42597: {'overlap': 5, 'num_in_same_order': 0},
#  132845: {'overlap': 4, 'num_in_same_order': 0},
#  41957: {'overlap': 1, 'num_in_same_order': 0},
#  196935: {'overlap': 1, 'num_in_same_order': 0},
#  15836: {'overlap': 1, 'num_in_same_order': 0},
#  81746: {'overlap': 2, 'num_in_same_order': 0},
#  15828: {'overlap': 2, 'num_in_same_order': 0},
#  15827: {'overlap': 3, 'num_in_same_order': 0},
#  25156: {'overlap': 3, 'num_in_same_order': 0},
#  5388: {'overlap': 6, 'num_in_same_order': 0},
#  282942: {'overlap': 2, 'num_in_same_order': 0},
#  49740: {'overlap': 8, 'num_in_same_order': 0},
#  180498: {'overlap': 5, 'num_in_same_order': 0},
#  180621: {'overlap': 6, 'num_in_same_order': 0},
#  180631: {'overlap': 5, 'num_in_same_order': 0},
#  180616: {'overlap': 5, 'num_in_same_order': 0},
#  65478: {'overlap': 4, 'num_in_same_order': 0},
#  47358: {'overlap': 7, 'num_in_same_order': 0},
#  91502: {'overlap': 7, 'num_in_same_order': 0},
#  19146: {'overlap': 7, 'num_in_same_order': 0},
#  54172: {'overlap': 3, 'num_in_same_order': 0},
#  91506: {'overlap': 4, 'num_in_same_order': 0},
#  239413: {'overlap': 4, 'num_in_same_order': 0},
#  54171: {'overlap': 6, 'num_in_same_order': 0},
#  65481: {'overlap': 4, 'num_in_same_order': 0},
#  126156: {'overlap': 4, 'num_in_same_order': 0},
#  18646: {'overlap': 5, 'num_in_same_order': 0},
#  42787: {'overlap': 3, 'num_in_same_order': 0},
#  7028: {'overlap': 8, 'num_in_same_order': 0},
#  17668: {'overlap': 8, 'num_in_same_order': 0},
#  1940: {'overlap': 6, 'num_in_same_order': 0},
#  9508: {'overlap': 5, 'num_in_same_order': 0},
#  9505: {'overlap': 8, 'num_in_same_order': 0},
#  1621: {'overlap': 8, 'num_in_same_order': 0},
#  1620: {'overlap': 4, 'num_in_same_order': 0},
#  7093: {'overlap': 5, 'num_in_same_order': 0},
#  126382: {'overlap': 5, 'num_in_same_order': 0},
#  14278: {'overlap': 4, 'num_in_same_order': 0},
#  15439: {'overlap': 6, 'num_in_same_order': 0},
#  28430: {'overlap': 4, 'num_in_same_order': 0},
#  33700: {'overlap': 4, 'num_in_same_order': 0},
#  33703: {'overlap': 5, 'num_in_same_order': 0},
#  83558: {'overlap': 4, 'num_in_same_order': 0},
#  83561: {'overlap': 4, 'num_in_same_order': 0},
#  35648: {'overlap': 8, 'num_in_same_order': 0},
#  45990: {'overlap': 3, 'num_in_same_order': 0},
#  7011: {'overlap': 9, 'num_in_same_order': 0},
#  25885: {'overlap': 7, 'num_in_same_order': 0},
#  9325: {'overlap': 5, 'num_in_same_order': 0},
#  18067: {'overlap': 6, 'num_in_same_order': 0},
#  35646: {'overlap': 8, 'num_in_same_order': 0},
#  46016: {'overlap': 1, 'num_in_same_order': 0},
#  46017: {'overlap': 2, 'num_in_same_order': 0},
#  46018: {'overlap': 2, 'num_in_same_order': 0},
#  15716: {'overlap': 11, 'num_in_same_order': 0},
#  4754: {'overlap': 3, 'num_in_same_order': 0},
#  7397: {'overlap': 8, 'num_in_same_order': 0},
#  7398: {'overlap': 9, 'num_in_same_order': 0},
#  45920: {'overlap': 6, 'num_in_same_order': 0},
#  2629: {'overlap': 5, 'num_in_same_order': 0},
#  15472: {'overlap': 4, 'num_in_same_order': 0},
#  211776: {'overlap': 3, 'num_in_same_order': 0},
#  26229: {'overlap': 5, 'num_in_same_order': 0},
#  35429: {'overlap': 5, 'num_in_same_order': 0},
#  7012: {'overlap': 6, 'num_in_same_order': 0},
#  36079: {'overlap': 6, 'num_in_same_order': 0},
#  165742: {'overlap': 2, 'num_in_same_order': 0},
#  25152: {'overlap': 4, 'num_in_same_order': 0},
#  423586: {'overlap': 3, 'num_in_same_order': 0},
#  1117: {'overlap': 7, 'num_in_same_order': 0},
#  1979: {'overlap': 5, 'num_in_same_order': 0},
#  1980: {'overlap': 4, 'num_in_same_order': 0},
#  19147: {'overlap': 8, 'num_in_same_order': 0},
#  22560: {'overlap': 6, 'num_in_same_order': 0},
#  71013: {'overlap': 4, 'num_in_same_order': 0},
#  90343: {'overlap': 4, 'num_in_same_order': 0},
#  90345: {'overlap': 3, 'num_in_same_order': 0},
#  90348: {'overlap': 2, 'num_in_same_order': 0},
#  71489: {'overlap': 6, 'num_in_same_order': 0},
#  83107: {'overlap': 6, 'num_in_same_order': 0},
#  28389: {'overlap': 6, 'num_in_same_order': 0},
#  11712: {'overlap': 3, 'num_in_same_order': 0},
#  102904: {'overlap': 3, 'num_in_same_order': 0},
#  97620: {'overlap': 2, 'num_in_same_order': 0},
#  1906: {'overlap': 3, 'num_in_same_order': 0},
#  7531: {'overlap': 2, 'num_in_same_order': 0},
#  71286: {'overlap': 7, 'num_in_same_order': 0},
#  71287: {'overlap': 5, 'num_in_same_order': 0},
#  1701: {'overlap': 4, 'num_in_same_order': 0},
#  12660: {'overlap': 6, 'num_in_same_order': 0},
#  22565: {'overlap': 5, 'num_in_same_order': 0},
#  1700: {'overlap': 4, 'num_in_same_order': 0},
#  41834: {'overlap': 4, 'num_in_same_order': 0},
#  15149: {'overlap': 3, 'num_in_same_order': 0},
#  3848: {'overlap': 6, 'num_in_same_order': 0},
#  48915: {'overlap': 3, 'num_in_same_order': 0},
#  3844: {'overlap': 7, 'num_in_same_order': 0},
#  42915: {'overlap': 6, 'num_in_same_order': 0},
#  126165: {'overlap': 7, 'num_in_same_order': 0},
#  126166: {'overlap': 6, 'num_in_same_order': 0},
#  126167: {'overlap': 7, 'num_in_same_order': 0},
#  4507: {'overlap': 10, 'num_in_same_order': 0},
#  4510: {'overlap': 10, 'num_in_same_order': 0},
#  4712: {'overlap': 6, 'num_in_same_order': 0},
#  15488: {'overlap': 2, 'num_in_same_order': 0},
#  15491: {'overlap': 2, 'num_in_same_order': 0},
#  3142: {'overlap': 6, 'num_in_same_order': 0},
#  35469: {'overlap': 9, 'num_in_same_order': 0},
#  35745: {'overlap': 3, 'num_in_same_order': 0},
#  133859: {'overlap': 2, 'num_in_same_order': 0},
#  21419: {'overlap': 7, 'num_in_same_order': 0},
#  18093: {'overlap': 7, 'num_in_same_order': 0},
#  35664: {'overlap': 5, 'num_in_same_order': 0},
#  11952: {'overlap': 1, 'num_in_same_order': 0},
#  451448: {'overlap': 3, 'num_in_same_order': 0},
#  9504: {'overlap': 5, 'num_in_same_order': 0},
#  35602: {'overlap': 9, 'num_in_same_order': 0},
#  35509: {'overlap': 6, 'num_in_same_order': 0},
#  18320: {'overlap': 3, 'num_in_same_order': 0},
#  35615: {'overlap': 5, 'num_in_same_order': 0},
#  6010: {'overlap': 2, 'num_in_same_order': 0},
#  226930: {'overlap': 1, 'num_in_same_order': 0},
#  226932: {'overlap': 2, 'num_in_same_order': 0},
#  7585: {'overlap': 11, 'num_in_same_order': 0},
#  35387: {'overlap': 9, 'num_in_same_order': 0},
#  35552: {'overlap': 9, 'num_in_same_order': 0},
#  214869: {'overlap': 5, 'num_in_same_order': 0},
#  280950: {'overlap': 3, 'num_in_same_order': 0},
#  292870: {'overlap': 1, 'num_in_same_order': 0},
#  16499: {'overlap': 4, 'num_in_same_order': 0},
#  126176: {'overlap': 11, 'num_in_same_order': 0},
#  14299: {'overlap': 7, 'num_in_same_order': 0},
#  35504: {'overlap': 5, 'num_in_same_order': 0},
#  173: {'overlap': 1, 'num_in_same_order': 0},
#  7482: {'overlap': 8, 'num_in_same_order': 0},
#  45125: {'overlap': 2, 'num_in_same_order': 0},
#  3763: {'overlap': 3, 'num_in_same_order': 0},
#  45367: {'overlap': 2, 'num_in_same_order': 0},
#  7104: {'overlap': 5, 'num_in_same_order': 0},
#  1611: {'overlap': 7, 'num_in_same_order': 0},
#  1612: {'overlap': 7, 'num_in_same_order': 0},
#  107628: {'overlap': 7, 'num_in_same_order': 0},
#  107629: {'overlap': 5, 'num_in_same_order': 0},
#  25932: {'overlap': 7, 'num_in_same_order': 0},
#  42438: {'overlap': 9, 'num_in_same_order': 0},
#  42439: {'overlap': 9, 'num_in_same_order': 0},
#  42445: {'overlap': 6, 'num_in_same_order': 0},
#  42448: {'overlap': 6, 'num_in_same_order': 0},
#  31640: {'overlap': 6, 'num_in_same_order': 0},
#  25928: {'overlap': 5, 'num_in_same_order': 0},
#  107630: {'overlap': 5, 'num_in_same_order': 0},
#  79648: {'overlap': 4, 'num_in_same_order': 0},
#  3420: {'overlap': 3, 'num_in_same_order': 0},
#  46065: {'overlap': 6, 'num_in_same_order': 0},
#  46066: {'overlap': 9, 'num_in_same_order': 0},
#  46071: {'overlap': 6, 'num_in_same_order': 0},
#  204791: {'overlap': 5, 'num_in_same_order': 0},
#  36097: {'overlap': 2, 'num_in_same_order': 0},
#  25518: {'overlap': 6, 'num_in_same_order': 0},
#  36095: {'overlap': 2, 'num_in_same_order': 0},
#  36096: {'overlap': 3, 'num_in_same_order': 0},
#  56744: {'overlap': 4, 'num_in_same_order': 0},
#  103029: {'overlap': 4, 'num_in_same_order': 0},
#  7025: {'overlap': 10, 'num_in_same_order': 0},
#  226956: {'overlap': 4, 'num_in_same_order': 0},
#  226963: {'overlap': 6, 'num_in_same_order': 0},
#  7450: {'overlap': 6, 'num_in_same_order': 0},
#  73031: {'overlap': 3, 'num_in_same_order': 0},
#  56933: {'overlap': 6, 'num_in_same_order': 0},
#  14470: {'overlap': 3, 'num_in_same_order': 0},
#  14479: {'overlap': 5, 'num_in_same_order': 0},
#  89469: {'overlap': 2, 'num_in_same_order': 0},
#  14471: {'overlap': 4, 'num_in_same_order': 0},
#  14477: {'overlap': 2, 'num_in_same_order': 0},
#  46328: {'overlap': 1, 'num_in_same_order': 0},
#  551119: {'overlap': 1, 'num_in_same_order': 0},
#  93598: {'overlap': 1, 'num_in_same_order': 0},
#  112967: {'overlap': 2, 'num_in_same_order': 0},
#  92738: {'overlap': 2, 'num_in_same_order': 0},
#  30369: {'overlap': 1, 'num_in_same_order': 0},
#  12846: {'overlap': 1, 'num_in_same_order': 0},
#  56165: {'overlap': 4, 'num_in_same_order': 0},
#  56166: {'overlap': 4, 'num_in_same_order': 0},
#  106392: {'overlap': 4, 'num_in_same_order': 0},
#  329598: {'overlap': 4, 'num_in_same_order': 0},
#  35378: {'overlap': 2, 'num_in_same_order': 0},
#  201268: {'overlap': 2, 'num_in_same_order': 0},
#  93499: {'overlap': 3, 'num_in_same_order': 0},
#  86395: {'overlap': 3, 'num_in_same_order': 0},
#  136327: {'overlap': 1, 'num_in_same_order': 0},
#  257758: {'overlap': 1, 'num_in_same_order': 0},
#  257759: {'overlap': 1, 'num_in_same_order': 0},
#  2871: {'overlap': 6, 'num_in_same_order': 0},
#  25649: {'overlap': 6, 'num_in_same_order': 0},
#  20693: {'overlap': 6, 'num_in_same_order': 0},
#  6959: {'overlap': 4, 'num_in_same_order': 0},
#  25645: {'overlap': 5, 'num_in_same_order': 0},
#  162749: {'overlap': 4, 'num_in_same_order': 0},
#  5137: {'overlap': 5, 'num_in_same_order': 0},
#  30178: {'overlap': 2, 'num_in_same_order': 0},
#  141408: {'overlap': 6, 'num_in_same_order': 0},
#  73617: {'overlap': 4, 'num_in_same_order': 0},
#  98516: {'overlap': 2, 'num_in_same_order': 0},
#  7134: {'overlap': 5, 'num_in_same_order': 0},
#  32616: {'overlap': 5, 'num_in_same_order': 0},
#  7137: {'overlap': 5, 'num_in_same_order': 0},
#  51162: {'overlap': 6, 'num_in_same_order': 0},
#  21002: {'overlap': 5, 'num_in_same_order': 0},
#  9649: {'overlap': 4, 'num_in_same_order': 0},
#  9651: {'overlap': 5, 'num_in_same_order': 0},
#  13614: {'overlap': 4, 'num_in_same_order': 0},
#  9653: {'overlap': 7, 'num_in_same_order': 0},
#  9652: {'overlap': 6, 'num_in_same_order': 0},
#  51161: {'overlap': 7, 'num_in_same_order': 0},
#  206419: {'overlap': 4, 'num_in_same_order': 0},
#  11623: {'overlap': 2, 'num_in_same_order': 0},
#  2940: {'overlap': 3, 'num_in_same_order': 0},
#  23353: {'overlap': 1, 'num_in_same_order': 0},
#  23354: {'overlap': 2, 'num_in_same_order': 0},
#  9199: {'overlap': 3, 'num_in_same_order': 0},
#  12205: {'overlap': 2, 'num_in_same_order': 0},
#  58954: {'overlap': 2, 'num_in_same_order': 0},
#  698: {'overlap': 1, 'num_in_same_order': 0},
#  178373: {'overlap': 1, 'num_in_same_order': 0},
#  8467: {'overlap': 2, 'num_in_same_order': 0},
#  8469: {'overlap': 1, 'num_in_same_order': 0},
#  62472: {'overlap': 3, 'num_in_same_order': 0},
#  9167: {'overlap': 10, 'num_in_same_order': 0},
#  9168: {'overlap': 10, 'num_in_same_order': 0},
#  91050: {'overlap': 2, 'num_in_same_order': 0},
#  35060: {'overlap': 1, 'num_in_same_order': 0},
#  80115: {'overlap': 2, 'num_in_same_order': 0},
#  409455: {'overlap': 1, 'num_in_same_order': 0},
#  140448: {'overlap': 4, 'num_in_same_order': 0},
#  27676: {'overlap': 4, 'num_in_same_order': 0},
#  5565: {'overlap': 5, 'num_in_same_order': 0},
#  9164: {'overlap': 3, 'num_in_same_order': 0},
#  53689: {'overlap': 2, 'num_in_same_order': 0},
#  8502: {'overlap': 3, 'num_in_same_order': 0},
#  8662: {'overlap': 6, 'num_in_same_order': 0},
#  8660: {'overlap': 5, 'num_in_same_order': 0},
#  173248: {'overlap': 3, 'num_in_same_order': 0},
#  260439: {'overlap': 4, 'num_in_same_order': 0},
#  260440: {'overlap': 4, 'num_in_same_order': 0},
#  3190: {'overlap': 2, 'num_in_same_order': 0},
#  3191: {'overlap': 2, 'num_in_same_order': 0},
#  38527: {'overlap': 1, 'num_in_same_order': 0},
#  51177: {'overlap': 1, 'num_in_same_order': 0},
#  89264: {'overlap': 1, 'num_in_same_order': 0},
#  40923: {'overlap': 2, 'num_in_same_order': 0},
#  311333: {'overlap': 2, 'num_in_same_order': 0},
#  311413: {'overlap': 1, 'num_in_same_order': 0},
#  217094: {'overlap': 1, 'num_in_same_order': 0},
#  55737: {'overlap': 7, 'num_in_same_order': 0},
#  48768: {'overlap': 1, 'num_in_same_order': 0},
#  75091: {'overlap': 2, 'num_in_same_order': 0},
#  75092: {'overlap': 1, 'num_in_same_order': 0},
#  35635: {'overlap': 4, 'num_in_same_order': 0},
#  766: {'overlap': 5, 'num_in_same_order': 0},
#  266225: {'overlap': 3, 'num_in_same_order': 0},
#  90126: {'overlap': 6, 'num_in_same_order': 0},
#  494825: {'overlap': 2, 'num_in_same_order': 0},
#  494826: {'overlap': 1, 'num_in_same_order': 0},
#  26693: {'overlap': 2, 'num_in_same_order': 0},
#  365033: {'overlap': 1, 'num_in_same_order': 0},
#  427963: {'overlap': 2, 'num_in_same_order': 0},
#  3687: {'overlap': 4, 'num_in_same_order': 0},
#  51463: {'overlap': 1, 'num_in_same_order': 0},
#  3703: {'overlap': 7, 'num_in_same_order': 0},
#  3706: {'overlap': 7, 'num_in_same_order': 0},
#  51461: {'overlap': 2, 'num_in_same_order': 0},
#  7109: {'overlap': 3, 'num_in_same_order': 0},
#  443477: {'overlap': 1, 'num_in_same_order': 0},
#  536503: {'overlap': 2, 'num_in_same_order': 0},
#  3760: {'overlap': 6, 'num_in_same_order': 0},
#  1610: {'overlap': 6, 'num_in_same_order': 0},
#  40186: {'overlap': 4, 'num_in_same_order': 0},
#  55669: {'overlap': 5, 'num_in_same_order': 0},
#  63213: {'overlap': 2, 'num_in_same_order': 0},
#  17091: {'overlap': 7, 'num_in_same_order': 0},
#  63174: {'overlap': 5, 'num_in_same_order': 0},
#  63323: {'overlap': 2, 'num_in_same_order': 0},
#  29997: {'overlap': 9, 'num_in_same_order': 0},
#  63318: {'overlap': 2, 'num_in_same_order': 0},
#  11294: {'overlap': 3, 'num_in_same_order': 0},
#  9392: {'overlap': 2, 'num_in_same_order': 0},
#  9383: {'overlap': 5, 'num_in_same_order': 0},
#  2572: {'overlap': 5, 'num_in_same_order': 0},
#  154478: {'overlap': 2, 'num_in_same_order': 0},
#  2575: {'overlap': 2, 'num_in_same_order': 0},
#  2573: {'overlap': 8, 'num_in_same_order': 0},
#  32745: {'overlap': 10, 'num_in_same_order': 0},
#  32743: {'overlap': 6, 'num_in_same_order': 0},
#  32746: {'overlap': 6, 'num_in_same_order': 0},
#  32747: {'overlap': 10, 'num_in_same_order': 0},
#  32744: {'overlap': 10, 'num_in_same_order': 0},
#  38468: {'overlap': 9, 'num_in_same_order': 0},
#  39872: {'overlap': 8, 'num_in_same_order': 0},
#  8574: {'overlap': 9, 'num_in_same_order': 0},
#  39869: {'overlap': 9, 'num_in_same_order': 0},
#  273151: {'overlap': 9, 'num_in_same_order': 0},
#  347569: {'overlap': 9, 'num_in_same_order': 0},
#  3102: {'overlap': 6, 'num_in_same_order': 0},
#  114216: {'overlap': 4, 'num_in_same_order': 0},
#  52129: {'overlap': 3, 'num_in_same_order': 0},
#  18213: {'overlap': 4, 'num_in_same_order': 0},
#  511: {'overlap': 6, 'num_in_same_order': 0},
#  17306: {'overlap': 4, 'num_in_same_order': 0},
#  601: {'overlap': 6, 'num_in_same_order': 0},
#  59061: {'overlap': 4, 'num_in_same_order': 0},
#  3101: {'overlap': 5, 'num_in_same_order': 0},
#  445: {'overlap': 4, 'num_in_same_order': 0},
#  121625: {'overlap': 2, 'num_in_same_order': 0},
#  36959: {'overlap': 4, 'num_in_same_order': 0},
#  8989: {'overlap': 4, 'num_in_same_order': 0},
#  136675: {'overlap': 2, 'num_in_same_order': 0},
#  18268: {'overlap': 3, 'num_in_same_order': 0},
#  9822: {'overlap': 1, 'num_in_same_order': 0},
#  48355: {'overlap': 3, 'num_in_same_order': 0},
#  123867: {'overlap': 2, 'num_in_same_order': 0},
#  81856: {'overlap': 2, 'num_in_same_order': 0},
#  17193: {'overlap': 1, 'num_in_same_order': 0},
#  17197: {'overlap': 4, 'num_in_same_order': 0},
#  76405: {'overlap': 3, 'num_in_same_order': 0},
#  20873: {'overlap': 5, 'num_in_same_order': 0},
#  129485: {'overlap': 5, 'num_in_same_order': 0},
#  16938: {'overlap': 2, 'num_in_same_order': 0},
#  16956: {'overlap': 1, 'num_in_same_order': 0},
#  658: {'overlap': 9, 'num_in_same_order': 0},
#  19148: {'overlap': 7, 'num_in_same_order': 0},
#  19151: {'overlap': 5, 'num_in_same_order': 0},
#  27485: {'overlap': 5, 'num_in_same_order': 0},
#  27488: {'overlap': 6, 'num_in_same_order': 0},
#  8659: {'overlap': 6, 'num_in_same_order': 0},
#  32540: {'overlap': 6, 'num_in_same_order': 0},
#  15997: {'overlap': 7, 'num_in_same_order': 0},
#  27399: {'overlap': 5, 'num_in_same_order': 0},
#  32543: {'overlap': 4, 'num_in_same_order': 0},
#  653: {'overlap': 7, 'num_in_same_order': 0},
#  655: {'overlap': 7, 'num_in_same_order': 0},
#  656: {'overlap': 7, 'num_in_same_order': 0},
#  660: {'overlap': 6, 'num_in_same_order': 0},
#  69945: {'overlap': 10, 'num_in_same_order': 0},
#  88243: {'overlap': 10, 'num_in_same_order': 0},
#  67190: {'overlap': 11, 'num_in_same_order': 0},
#  190990: {'overlap': 10, 'num_in_same_order': 0},
#  190994: {'overlap': 11, 'num_in_same_order': 0},
#  190996: {'overlap': 10, 'num_in_same_order': 0},
#  265536: {'overlap': 1, 'num_in_same_order': 0},
#  265540: {'overlap': 1, 'num_in_same_order': 0},
#  19309: {'overlap': 1, 'num_in_same_order': 0},
#  48688: {'overlap': 2, 'num_in_same_order': 0},
#  26338: {'overlap': 3, 'num_in_same_order': 0},
#  72130: {'overlap': 4, 'num_in_same_order': 0},
#  39581: {'overlap': 8, 'num_in_same_order': 0},
#  39583: {'overlap': 8, 'num_in_same_order': 0},
#  39584: {'overlap': 7, 'num_in_same_order': 0},
#  39608: {'overlap': 5, 'num_in_same_order': 0},
#  39784: {'overlap': 3, 'num_in_same_order': 0},
#  39582: {'overlap': 5, 'num_in_same_order': 0},
#  39586: {'overlap': 5, 'num_in_same_order': 0},
#  39593: {'overlap': 5, 'num_in_same_order': 0},
#  39640: {'overlap': 4, 'num_in_same_order': 0},
#  39602: {'overlap': 4, 'num_in_same_order': 0},
#  31492: {'overlap': 8, 'num_in_same_order': 0},
#  464003: {'overlap': 2, 'num_in_same_order': 0},
#  464052: {'overlap': 3, 'num_in_same_order': 0},
#  53733: {'overlap': 4, 'num_in_same_order': 0},
#  53734: {'overlap': 6, 'num_in_same_order': 0},
#  464091: {'overlap': 2, 'num_in_same_order': 0},
#  464093: {'overlap': 1, 'num_in_same_order': 0},
#  464094: {'overlap': 2, 'num_in_same_order': 0},
#  38556: {'overlap': 2, 'num_in_same_order': 0},
#  35675: {'overlap': 5, 'num_in_same_order': 0},
#  35679: {'overlap': 5, 'num_in_same_order': 0},
#  145736: {'overlap': 5, 'num_in_same_order': 0},
#  35677: {'overlap': 6, 'num_in_same_order': 0},
#  359647: {'overlap': 3, 'num_in_same_order': 0},
#  155864: {'overlap': 3, 'num_in_same_order': 0},
#  359665: {'overlap': 1, 'num_in_same_order': 0},
#  359664: {'overlap': 1, 'num_in_same_order': 0},
#  359667: {'overlap': 1, 'num_in_same_order': 0},
#  359668: {'overlap': 3, 'num_in_same_order': 0},
#  359670: {'overlap': 2, 'num_in_same_order': 0},
#  359671: {'overlap': 2, 'num_in_same_order': 0},
#  359674: {'overlap': 2, 'num_in_same_order': 0},
#  359675: {'overlap': 2, 'num_in_same_order': 0},
#  2888: {'overlap': 3, 'num_in_same_order': 0},
#  39759: {'overlap': 2, 'num_in_same_order': 0},
#  39760: {'overlap': 1, 'num_in_same_order': 0},
#  10721: {'overlap': 3, 'num_in_same_order': 0},
#  6001: {'overlap': 5, 'num_in_same_order': 0},
#  6002: {'overlap': 5, 'num_in_same_order': 0},
#  59815: {'overlap': 7, 'num_in_same_order': 0},
#  59817: {'overlap': 7, 'num_in_same_order': 0},
#  59854: {'overlap': 8, 'num_in_same_order': 0},
#  59888: {'overlap': 6, 'num_in_same_order': 0},
#  308445: {'overlap': 5, 'num_in_same_order': 0},
#  308444: {'overlap': 6, 'num_in_same_order': 0},
#  59814: {'overlap': 5, 'num_in_same_order': 0},
#  59816: {'overlap': 4, 'num_in_same_order': 0},
#  103664: {'overlap': 5, 'num_in_same_order': 0},
#  59856: {'overlap': 8, 'num_in_same_order': 0},
#  59857: {'overlap': 6, 'num_in_same_order': 0},
#  103672: {'overlap': 6, 'num_in_same_order': 0},
#  20140: {'overlap': 6, 'num_in_same_order': 0},
#  20142: {'overlap': 4, 'num_in_same_order': 0},
#  20141: {'overlap': 5, 'num_in_same_order': 0},
#  83809: {'overlap': 7, 'num_in_same_order': 0},
#  345224: {'overlap': 4, 'num_in_same_order': 0},
#  345225: {'overlap': 4, 'num_in_same_order': 0},
#  345226: {'overlap': 5, 'num_in_same_order': 0},
#  347: {'overlap': 6, 'num_in_same_order': 0},
#  207636: {'overlap': 7, 'num_in_same_order': 0},
#  221189: {'overlap': 7, 'num_in_same_order': 0},
#  261342: {'overlap': 6, 'num_in_same_order': 0},
#  345227: {'overlap': 4, 'num_in_same_order': 0},
#  18231: {'overlap': 2, 'num_in_same_order': 0},
#  74549: {'overlap': 2, 'num_in_same_order': 0},
#  74564: {'overlap': 2, 'num_in_same_order': 0},
#  74537: {'overlap': 3, 'num_in_same_order': 0},
#  29713: {'overlap': 2, 'num_in_same_order': 0},
#  26294: {'overlap': 4, 'num_in_same_order': 0},
#  8400: {'overlap': 1, 'num_in_same_order': 0},
#  1798: {'overlap': 3, 'num_in_same_order': 0},
#  20168: {'overlap': 4, 'num_in_same_order': 0},
#  20485: {'overlap': 1, 'num_in_same_order': 0},
#  34790: {'overlap': 2, 'num_in_same_order': 0},
#  124703: {'overlap': 1, 'num_in_same_order': 0},
#  26281: {'overlap': 3, 'num_in_same_order': 0},
#  124704: {'overlap': 1, 'num_in_same_order': 0},
#  37181: {'overlap': 1, 'num_in_same_order': 0},
#  84128: {'overlap': 4, 'num_in_same_order': 0},
#  159224: {'overlap': 4, 'num_in_same_order': 0},
#  176403: {'overlap': 2, 'num_in_same_order': 0},
#  463739: {'overlap': 1, 'num_in_same_order': 0},
#  123: {'overlap': 3, 'num_in_same_order': 0},
#  3850: {'overlap': 7, 'num_in_same_order': 0},
#  231524: {'overlap': 1, 'num_in_same_order': 0},
#  463864: {'overlap': 1, 'num_in_same_order': 0},
#  19890: {'overlap': 7, 'num_in_same_order': 0},
#  15543: {'overlap': 4, 'num_in_same_order': 0},
#  13060: {'overlap': 6, 'num_in_same_order': 0},
#  15544: {'overlap': 6, 'num_in_same_order': 0},
#  12766: {'overlap': 5, 'num_in_same_order': 0},
#  293059: {'overlap': 2, 'num_in_same_order': 0},
#  8882: {'overlap': 6, 'num_in_same_order': 0},
#  27015: {'overlap': 3, 'num_in_same_order': 0},
#  19851: {'overlap': 9, 'num_in_same_order': 0},
#  1211: {'overlap': 2, 'num_in_same_order': 0},
#  157218: {'overlap': 1, 'num_in_same_order': 0},
#  1215: {'overlap': 5, 'num_in_same_order': 0},
#  153159: {'overlap': 6, 'num_in_same_order': 0},
#  153157: {'overlap': 5, 'num_in_same_order': 0},
#  551251: {'overlap': 6, 'num_in_same_order': 0},
#  551265: {'overlap': 6, 'num_in_same_order': 0},
#  153158: {'overlap': 5, 'num_in_same_order': 0},
#  153165: {'overlap': 6, 'num_in_same_order': 0},
#  551271: {'overlap': 5, 'num_in_same_order': 0},
#  463855: {'overlap': 2, 'num_in_same_order': 0},
#  13049: {'overlap': 3, 'num_in_same_order': 0},
#  102309: {'overlap': 5, 'num_in_same_order': 0},
#  28383: {'overlap': 3, 'num_in_same_order': 0},
#  11748: {'overlap': 2, 'num_in_same_order': 0},
#  47613: {'overlap': 1, 'num_in_same_order': 0},
#  39506: {'overlap': 6, 'num_in_same_order': 0},
#  5599: {'overlap': 7, 'num_in_same_order': 0},
#  5557: {'overlap': 7, 'num_in_same_order': 0},
#  5561: {'overlap': 6, 'num_in_same_order': 0},
#  5566: {'overlap': 7, 'num_in_same_order': 0},
#  5568: {'overlap': 7, 'num_in_same_order': 0},
#  71109: {'overlap': 3, 'num_in_same_order': 0},
#  6017: {'overlap': 5, 'num_in_same_order': 0},
#  102307: {'overlap': 3, 'num_in_same_order': 0},
#  5563: {'overlap': 8, 'num_in_same_order': 0},
#  5564: {'overlap': 4, 'num_in_same_order': 0},
#  5569: {'overlap': 6, 'num_in_same_order': 0},
#  9: {'overlap': 5, 'num_in_same_order': 0},
#  16442: {'overlap': 4, 'num_in_same_order': 0},
#  47707: {'overlap': 6, 'num_in_same_order': 0},
#  218208: {'overlap': 2, 'num_in_same_order': 0},
#  854: {'overlap': 3, 'num_in_same_order': 0},
#  495918: {'overlap': 1, 'num_in_same_order': 0},
#  3315: {'overlap': 2, 'num_in_same_order': 0},
#  147813: {'overlap': 1, 'num_in_same_order': 0},
#  495994: {'overlap': 1, 'num_in_same_order': 0},
#  113491: {'overlap': 3, 'num_in_same_order': 0},
#  84462: {'overlap': 6, 'num_in_same_order': 0},
#  24531: {'overlap': 3, 'num_in_same_order': 0},
#  24532: {'overlap': 2, 'num_in_same_order': 0},
#  24533: {'overlap': 4, 'num_in_same_order': 0},
#  24534: {'overlap': 3, 'num_in_same_order': 0},
#  293360: {'overlap': 3, 'num_in_same_order': 0},
#  293363: {'overlap': 4, 'num_in_same_order': 0},
#  293365: {'overlap': 3, 'num_in_same_order': 0},
#  293367: {'overlap': 2, 'num_in_same_order': 0},
#  82125: {'overlap': 5, 'num_in_same_order': 0},
#  177903: {'overlap': 5, 'num_in_same_order': 0},
#  177904: {'overlap': 5, 'num_in_same_order': 0},
#  293523: {'overlap': 3, 'num_in_same_order': 0},
#  11617: {'overlap': 3, 'num_in_same_order': 0},
#  150065: {'overlap': 4, 'num_in_same_order': 0},
#  293520: {'overlap': 3, 'num_in_same_order': 0},
#  293522: {'overlap': 3, 'num_in_same_order': 0},
#  32182: {'overlap': 4, 'num_in_same_order': 0},
#  197408: {'overlap': 6, 'num_in_same_order': 0},
#  197269: {'overlap': 2, 'num_in_same_order': 0},
#  197377: {'overlap': 2, 'num_in_same_order': 0},
#  203848: {'overlap': 4, 'num_in_same_order': 0},
#  18592: {'overlap': 5, 'num_in_same_order': 0},
#  43133: {'overlap': 4, 'num_in_same_order': 0},
#  43195: {'overlap': 4, 'num_in_same_order': 0},
#  38804: {'overlap': 2, 'num_in_same_order': 0},
#  82017: {'overlap': 2, 'num_in_same_order': 0},
#  82018: {'overlap': 3, 'num_in_same_order': 0},
#  82021: {'overlap': 2, 'num_in_same_order': 0},
#  41141: {'overlap': 7, 'num_in_same_order': 0},
#  43049: {'overlap': 7, 'num_in_same_order': 0},
#  3146: {'overlap': 6, 'num_in_same_order': 0},
#  3147: {'overlap': 5, 'num_in_same_order': 0},
#  17715: {'overlap': 4, 'num_in_same_order': 0},
#  17720: {'overlap': 5, 'num_in_same_order': 0},
#  17716: {'overlap': 3, 'num_in_same_order': 0},
#  133698: {'overlap': 2, 'num_in_same_order': 0},
#  293325: {'overlap': 2, 'num_in_same_order': 0},
#  49657: {'overlap': 6, 'num_in_same_order': 0},
#  293328: {'overlap': 1, 'num_in_same_order': 0},
#  58383: {'overlap': 4, 'num_in_same_order': 0},
#  43059: {'overlap': 5, 'num_in_same_order': 0},
#  293692: {'overlap': 4, 'num_in_same_order': 0},
#  29165: {'overlap': 4, 'num_in_same_order': 0},
#  103993: {'overlap': 2, 'num_in_same_order': 0},
#  103995: {'overlap': 2, 'num_in_same_order': 0},
#  103996: {'overlap': 3, 'num_in_same_order': 0},
#  103997: {'overlap': 2, 'num_in_same_order': 0},
#  103998: {'overlap': 3, 'num_in_same_order': 0},
#  65354: {'overlap': 3, 'num_in_same_order': 0},
#  39845: {'overlap': 8, 'num_in_same_order': 0},
#  7006: {'overlap': 2, 'num_in_same_order': 0},
#  39832: {'overlap': 5, 'num_in_same_order': 0},
#  11207: {'overlap': 2, 'num_in_same_order': 0},
#  1212: {'overlap': 6, 'num_in_same_order': 0},
#  28570: {'overlap': 10, 'num_in_same_order': 0},
#  43046: {'overlap': 9, 'num_in_same_order': 0},
#  82053: {'overlap': 4, 'num_in_same_order': 0},
#  114374: {'overlap': 3, 'num_in_same_order': 0},
#  114375: {'overlap': 2, 'num_in_same_order': 0},
#  38911: {'overlap': 6, 'num_in_same_order': 0},
#  43073: {'overlap': 4, 'num_in_same_order': 0},
#  43114: {'overlap': 3, 'num_in_same_order': 0},
#  123450: {'overlap': 3, 'num_in_same_order': 0},
#  43067: {'overlap': 3, 'num_in_same_order': 0},
#  43057: {'overlap': 9, 'num_in_same_order': 0},
#  43319: {'overlap': 6, 'num_in_same_order': 0},
#  43321: {'overlap': 7, 'num_in_same_order': 0},
#  43323: {'overlap': 4, 'num_in_same_order': 0},
#  43325: {'overlap': 4, 'num_in_same_order': 0},
#  12887: {'overlap': 5, 'num_in_same_order': 0},
#  43078: {'overlap': 8, 'num_in_same_order': 0},
#  3579: {'overlap': 7, 'num_in_same_order': 0},
#  3580: {'overlap': 4, 'num_in_same_order': 0},
#  3581: {'overlap': 8, 'num_in_same_order': 0},
#  3583: {'overlap': 11, 'num_in_same_order': 0},
#  3586: {'overlap': 8, 'num_in_same_order': 0},
#  75563: {'overlap': 6, 'num_in_same_order': 0},
#  75564: {'overlap': 9, 'num_in_same_order': 0},
#  43129: {'overlap': 5, 'num_in_same_order': 0},
#  43127: {'overlap': 3, 'num_in_same_order': 0},
#  43124: {'overlap': 6, 'num_in_same_order': 0},
#  43121: {'overlap': 2, 'num_in_same_order': 0},
#  43304: {'overlap': 3, 'num_in_same_order': 0},
#  43339: {'overlap': 3, 'num_in_same_order': 0},
#  117707: {'overlap': 2, 'num_in_same_order': 0},
#  117703: {'overlap': 3, 'num_in_same_order': 0},
#  71536: {'overlap': 7, 'num_in_same_order': 0},
#  3110: {'overlap': 3, 'num_in_same_order': 0},
#  3114: {'overlap': 1, 'num_in_same_order': 0},
#  793: {'overlap': 2, 'num_in_same_order': 0},
#  70471: {'overlap': 1, 'num_in_same_order': 0},
#  267639: {'overlap': 1, 'num_in_same_order': 0},
#  3111: {'overlap': 1, 'num_in_same_order': 0},
#  6967: {'overlap': 2, 'num_in_same_order': 0},
#  6968: {'overlap': 2, 'num_in_same_order': 0},
#  25608: {'overlap': 4, 'num_in_same_order': 0},
#  25727: {'overlap': 4, 'num_in_same_order': 0},
#  25731: {'overlap': 3, 'num_in_same_order': 0},
#  6969: {'overlap': 4, 'num_in_same_order': 0},
#  55770: {'overlap': 1, 'num_in_same_order': 0},
#  55767: {'overlap': 4, 'num_in_same_order': 0},
#  55833: {'overlap': 2, 'num_in_same_order': 0},
#  55834: {'overlap': 2, 'num_in_same_order': 0},
#  250781: {'overlap': 4, 'num_in_same_order': 0},
#  363850: {'overlap': 4, 'num_in_same_order': 0},
#  363975: {'overlap': 1, 'num_in_same_order': 0},
#  34869: {'overlap': 3, 'num_in_same_order': 0},
#  534860: {'overlap': 3, 'num_in_same_order': 0},
#  534862: {'overlap': 3, 'num_in_same_order': 0},
#  379943: {'overlap': 1, 'num_in_same_order': 0},
#  ...}
