# %% [markdown]
# # EDA - Segment Overview
#
# Description: Analysis of the Timbre vectors that are given for every song segment.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

pd.set_option('display.max_columns', 500)

# %% [markdown]
# ## What do we know About the Timbre?
#
# taken from - https://www.youtube.com/watch?v=goUzHd7cTuA&feature=youtu.be
#
# - Timbre is effectively how sound works
# - The quality of a musical note or sound that distinguishes different types of musical instruments or voices.
# - Represented as a vector that includes 12 unbounded values roughly centered around 0.
#
# ### Vector Breakdown:
# - 1st dimension represents avg loudness of the segment
# - 2nd emphasizes brightness
# - 3rd correlated with the flatness of the sound
# - 4th to sounds with a stronger attack
#
# *They are best used in comparison with each other. i.e., if there's a lot of repetetive values b/w sections, you could gather that the song itself is quite repetitive.*
# The timbre features themselves have been PCA'd into the 12 most important features (see above).

# %% [markdown]
# ##### Importing Song Listing for Analysis

# %%
main_song_list = pd.read_csv('../data/main_wfeats.csv', index_col='song_id')
main_song_list.drop('Unnamed: 0', 1, inplace=True)

# %%
main_song_list.columns
# Out:
# Index(['album_release_date', 'artist_id', 'artist_name', 'duration_ms',
#        'explicit', 'linked_album', 'song_title', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'key_changes', 'mean_song_conf', 'mean_loudness', 'mean_mode',
#        'mean_mode_conf', 'mean_tempo', 'mean_tempo_conf', 'var_song_conf',
#        'var_loudness', 'var_mode', 'var_mode_conf', 'var_tempo',
#        'var_tempo_conf', 'tm_dim_1', 'tm_dim_2', 'tm_dim_3', 'tm_dim_4',
#        'tm_dim_5', 'tm_dim_6', 'tm_dim_7', 'tm_dim_8', 'tm_dim_9', 'tm_dim_10',
#        'tm_dim_11', 'tm_dim_12', 'tv_dim_1', 'tv_dim_2', 'tv_dim_3',
#        'tv_dim_4', 'tv_dim_5', 'tv_dim_6', 'tv_dim_7', 'tv_dim_8', 'tv_dim_9',
#        'tv_dim_10', 'tv_dim_11', 'tv_dim_12', 'pm_dim_1', 'pm_dim_2',
#        'pm_dim_3', 'pm_dim_4', 'pm_dim_5', 'pm_dim_6', 'pm_dim_7', 'pm_dim_8',
# ...

# %% [markdown]
# ## Timbre Dimension 5

# %% [markdown]
# ##### Description:
#
# Meta:
# - All relatively low energy
# - Very sparse, in terms of sounds
#
# 1. Lotta Bells!! lotta echoing of said bells (instrumental)
# 2. old timey rock rendition of a classic song + a cover of fur elise that starts out on piano, and then becomes old timey classic rock again (instrumental)
# 3. SOOOOO SPARRRSSEE and weird sounding, eventually speeds up and becomes more "full" around 2min mark. Vocals come in around ~3. Gets hella sparse again around 6min mark. Wikipedia description:
# > "The Endless Enigma" consists of three parts; the first section begins with the sound of a beating heart, an effect sometimes claimed to have been created by the Ludwig Speed King bass drum pedal of Palmer's Ludwig Octaplus kit. However, in the sleeve notes to the 2015 CD/DVD reissue, remix engineer Jakko Jakszyk is quoted as saying "It starts with a heartbeat which I've discovered is actually Greg [Lake] playing... muted strings on his bass guitar."

# %% [markdown]
# #### Mean Values

# %%
main_song_list.sort_values(['tm_dim_5'], axis=0, ascending=False).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 5kPvX0P6jkZHCVjqGbOIBp         2017-06-02  7M1FPw29m5FbicYzS2xdpi
# 3Pf3Q0dMxbjIm8APJI6zot               1968  0vIMq3W8V63uR4Ymgm2pF1
# 04mgrGPxkikkJ0CPeUtG8R         1972-07-06  0nCiidE5GgDrc5kWN3NZgZ
# 0e5StRkQJonuMRjajfyGwp               2008  6zB02lwP6L6ZH32nggQiJT
# 57goBNSlWZOTn2bLDm1L0s         1988-03-21  58Dx4HPzeOO3dbpD9YYEes
#
#                                    artist_name  duration_ms  explicit  \
# song_id
# 5kPvX0P6jkZHCVjqGbOIBp            King Crimson     636644.0     False
# 3Pf3Q0dMxbjIm8APJI6zot           Vanilla Fudge     396133.0     False
# 04mgrGPxkikkJ0CPeUtG8R  Emerson, Lake & Palmer     403560.0     False
# 0e5StRkQJonuMRjajfyGwp    They Might Be Giants      55253.0     False
# 57goBNSlWZOTn2bLDm1L0s             2 LIVE CREW     241466.0      True
#
#                                                              linked_album  \
# song_id
# ...

# %% [markdown]
# ## Timbre Dimension 6

# %% [markdown]
# ##### Description:
#
# **Maybe call this: "Net Rhythm"**
#
# Has:
# - Songs which have high Dim 6 means appear to have realitvely sparse production, or less "full" sound, which is a characteristic of many late-80's / early-90's hip hop titles. All of the works are considered very "danceable" as well, and have very prominent drum beats.
#
# Doesn't Have:
# - Each of the song titles lacking in Dim 6 are either a) orchestral arrangements (from soundtracks or otherwise) or b) Choral works. Very distinct lack of drum beats and extremely low danceability numbers

# %%
main_song_list.sort_values(['tm_dim_6'], axis=0, ascending=False).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 6JMIaVMbh5emijDiBODgit               1987  4toEjJSZu1rbfX2hfVdZFA
# 3G3lahQSMk4BHnap1i853u               1988  2eynOGnZLqDuEJwbRHlHN1
# 0o8Ki6DTyYWjleWnDlMUhw         2016-09-09  4BIQA9vRkqXEnA2twmq7mU
# 3Cx9j78Z0NE6jYwBWvvV3P         1992-06-01  0EdvGhlC1FkGItLOWQzG4J
# 48qTCJuwPM58ufWVVyg64B         2012-04-06  4AWzJ0jYO43xrWkQ4O7R5x
#
#                                     artist_name  duration_ms  explicit  \
# song_id
# 6JMIaVMbh5emijDiBODgit  Boogie Down Productions     308558.0      True
# 3G3lahQSMk4BHnap1i853u                 J.J. Fad     232306.0     False
# 0o8Ki6DTyYWjleWnDlMUhw             Mario Winans     219011.0     False
# 3Cx9j78Z0NE6jYwBWvvV3P                  Sublime     140226.0      True
# 48qTCJuwPM58ufWVVyg64B      Mr. C The Slide Man     433986.0     False
#
#                                               linked_album  \
# song_id
# ...

# %%
main_song_list.sort_values(['tm_dim_6'], axis=0, ascending=True).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 0cKqpI6pOYeNFK2HPuMHXc         2009-06-09  6AWGppAWm4CeFbR94UnEb0
# 1ghqlcFUP85h1Gxn4Oa2Kt               1990  7ctAOUlIAs7yuMODWE2Fyz
# 5lu4pwb800iNz4cA5iaaoZ         2003-05-06  2duo4NJtUrLaI38trK0hht
# 23ryVoyGTrfO3F0GblIfnz               1986  430byzy0c5bPn5opiu0SRd
# 5JHtfM9QWN8pgcMP8Dejt8               1992  4DAmH51BfQpej5UEP0dZ3u
#
#                                     artist_name  duration_ms  explicit  \
# song_id
# 0cKqpI6pOYeNFK2HPuMHXc            FELIX MEAGHER      95546.0     False
# 1ghqlcFUP85h1Gxn4Oa2Kt               John Barry     137773.0     False
# 5lu4pwb800iNz4cA5iaaoZ  Mormon Tabernacle Choir     302293.0     False
# 23ryVoyGTrfO3F0GblIfnz             Edward Elgar     234133.0     False
# 5JHtfM9QWN8pgcMP8Dejt8             Hubert Parry     138333.0     False
#
#                                                              linked_album  \
# song_id
# ...

# %% [markdown]
# ## Timbre Dimension 7

# %% [markdown]
# ##### Description
# Really unsure that I can come up with something here.
#
# **Nickname TBD**
#
# Has:
# - Very slow, so far. Low energy titles. Every piece starts off with low instrumentation
#
# Doesn't Have:
# - First song is JUST flute. Though energy is also lacking. Third song is the same
# - Second track is very fast paced, in your face instrumental rock
# - The net energy of all examples combined is higher, though some individual tracks are severly lacking in energy.

# %%
main_song_list.sort_values(['tm_dim_7'], axis=0, ascending=False).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 1PPTlPJqKuL0fdoTmzwXJy         2004-05-25  3dRfiJ2650SZu6GbydcHNb
# 1QDXntUSJuoqA3uvDYICxY         1971-01-01  30orN5PtRhj9fN2Myr8HKV
# 74CrNr1IJHwrhYnrp8sMde               1982  3jdODvx7rIdq0UGU7BOVR3
# 3XIlw0G91i34Hr13m41YXi         2015-05-04  5tF14orX4tFSqVIm4oA9XD
# 7usOQQRtN6hgW7R0OJu2wz               1989  7ukOC5U2oweIhxAm26BNF7
#
#                                   artist_name  duration_ms  explicit  \
# song_id
# 1PPTlPJqKuL0fdoTmzwXJy          John Williams     234040.0     False
# 1QDXntUSJuoqA3uvDYICxY  Harry Simeone Chorale     141688.0     False
# 74CrNr1IJHwrhYnrp8sMde         George Winston     239706.0     False
# 3XIlw0G91i34Hr13m41YXi           WordHarmonic     254773.0     False
# 7usOQQRtN6hgW7R0OJu2wz              Ray Lynch     337240.0     False
#
#                                                              linked_album  \
# song_id
# ...

# %%
main_song_list.sort_values(['tm_dim_7'], axis=0, ascending=True).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 1SccyQeGE05N2ac1JF2MRW         2013-10-15  0PRSELwINaU945xsPKJ6mt
# 6wPA3Eplol740Hftfbu3nY         1994-01-01  2QMMktUMtwMSwUZATX1cRO
# 4JCxnuRAeiMnPS8EuYOT1Q         2013-10-15  0PRSELwINaU945xsPKJ6mt
# 6XbejJOw5nDizAauzz4j7t               2005  2LvhyFvUCDJ7gFuEBOcrM8
# 7FlwylpJSe3ea6m1IrkizS         1986-03-24  2ycnb8Er79LoH2AsR5ldjh
#
#                              artist_name  duration_ms  explicit  \
# song_id
# 1SccyQeGE05N2ac1JF2MRW  David R. Maracle     170906.0     False
# 6wPA3Eplol740Hftfbu3nY           Toadies     108200.0     False
# 4JCxnuRAeiMnPS8EuYOT1Q  David R. Maracle     136946.0     False
# 6XbejJOw5nDizAauzz4j7t     Michael Nyman     225186.0     False
# 7FlwylpJSe3ea6m1IrkizS     Pet Shop Boys     245360.0     False
#
#                                                           linked_album  \
# song_id
# 1SccyQeGE05N2ac1JF2MRW                                   Spirit Flutes
# ...

# %% [markdown]
# ## Timbre Dimension 8

# %% [markdown]
# **Bounce?**
#
# Has:
# - Slow, rhythmic....cool sounding (1st track)
# - "Bounce" (esp. 2nd track)
# - 3rd song is NOT A SONG (trouble)
# - 4th song does not have any drums, but there is a sort of swing or bounce with the vocals. It's an a capella
#
# Doesn't Have:
# - Way more in your face, high-energy
# - Metal-ish. Definitely lacking in bounce

# %%
main_song_list.sort_values(['tm_dim_8'], axis=0, ascending=False).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 6kXBteYQsR9tCoArL8V5mD         2001-07-31  3uISNNuONokIh21KiNharS
# 7yotKA30dwTKNEGomV9ZsI         2018-04-20  6l3HvQ5sa6mXTsMTB19rO5
# 59rnjWXXJaR61GgOFipbfA               1972  1tcGS3XC47Yf5VFNzJ1rfW
# 57rQttEMdycuH5hJkk6CSt               2006  0TcYeHEK9sBtv7xPbKhzHz
# 0Iiig94rtm9br1mx1fRhRV         2018-06-08  1pPmIToKXyGdsCF6LmqLmI
#
#                           artist_name  duration_ms  explicit  \
# song_id
# 6kXBteYQsR9tCoArL8V5mD  Butch Cassidy     312000.0      True
# 7yotKA30dwTKNEGomV9ZsI        J. Cole     191436.0      True
# 59rnjWXXJaR61GgOFipbfA     Mel Brooks     147880.0     False
# 57rQttEMdycuH5hJkk6CSt    Chumbawamba      96413.0     False
# 0Iiig94rtm9br1mx1fRhRV   Rich The Kid     169488.0      True
#
#                                                  linked_album  \
# song_id
# 6kXBteYQsR9tCoArL8V5mD  Duces 'N Trayz: The Old Fashioned Way
# ...

# %%
main_song_list.sort_values(['tm_dim_8'], axis=0, ascending=True).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 2Wjo03PLbjEzGCAv351lzP         1986-09-16  2hnzQ6eCFkxUIPsVcsdj8A
# 59y8ZGcD7iC5opfJwaTGiH         2018-03-23  4hvwEwrCmGj22uURGVET7Q
# 7JwnQlkaGMV2robELlKy9Y         2009-03-31  1DXylZlWbVvlckNqwvjTEt
# 2D9LxUcR9zWxQtxiHsMA0n         1992-07-10  1DXylZlWbVvlckNqwvjTEt
# 5kxjIRL11yyWLjrAPzYObI               1985  49DW3KvkyjHO35mK1JnSyS
#
#                                    artist_name  duration_ms  explicit  \
# song_id
# 2Wjo03PLbjEzGCAv351lzP  The Georgia Satellites     224533.0     False
# 59y8ZGcD7iC5opfJwaTGiH          Monster Magnet     209922.0     False
# 7JwnQlkaGMV2robELlKy9Y                Ministry     181506.0     False
# 2D9LxUcR9zWxQtxiHsMA0n                Ministry     330706.0     False
# 5kxjIRL11yyWLjrAPzYObI                The Cult     237213.0     False
#
#                                    linked_album            song_title  \
# song_id
# ...

# %% [markdown]
# ## Timbre Dimension 9

# %% [markdown]
# **Whimsical Sounds**
#
# Has:
# - First song has a xylophone/marimba prominently featured (topline melody)
# - No Xylophones, but a light section of violins prominently featured in the second song. Topline is opera singer (Whimsy)?
# - Fourth song I guess has the same sort of feeling with the synth xylophone like pattern
#
# Doesn't Have:
# - Fast paced, energetic rock from the Toadies with the first song. NO WHIMSY
# - Same with Casual Affair and No W
# - The Flogging Molly song has a more whimsical "feel", but again, huge lack of whimsical (marimba-like) instrumentation

# %%
main_song_list.sort_values(['tm_dim_9'], axis=0, ascending=False).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 12WzRi65tKh6DoFxY39YtJ               2005  2p0UyoPfYfI76PCStuXfOP
# 0et5aqL288PmhZOfXoxDhq         2006-01-01  0Y8KmFkKOgJybpVobn1onU
# 78Db46fhikqzs3XXbfyA51         1993-01-01  7hEbJvh3BAedDS2vVJvx0B
# 0cNJ3huiV99wvUN1tmQLTL         2010-01-01  3vDUJHQtqT3jFRZ2ECXDTi
# 4qOjQyUGIt71KKBX8e0S65         2011-06-01  0k3XbZNQTR8KVW2yWyJDDx
#
#                               artist_name  duration_ms  explicit  \
# song_id
# 12WzRi65tKh6DoFxY39YtJ     Franz Schubert     126666.0     False
# 0et5aqL288PmhZOfXoxDhq  Luciano Pavarotti     141333.0     False
# 78Db46fhikqzs3XXbfyA51      Andy Griffith     137506.0     False
# 0cNJ3huiV99wvUN1tmQLTL        Lloyd Banks     208386.0      True
# 4qOjQyUGIt71KKBX8e0S65         Earl Grant     162080.0     False
#
#                                              linked_album  \
# song_id
# 12WzRi65tKh6DoFxY39YtJ  Baby Einstein: Traveling Melodies
# ...

# %%
main_song_list.sort_values(['tm_dim_9'], axis=0, ascending=True).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 6wPA3Eplol740Hftfbu3nY         1994-01-01  2QMMktUMtwMSwUZATX1cRO
# 7JwnQlkaGMV2robELlKy9Y         2009-03-31  1DXylZlWbVvlckNqwvjTEt
# 1SccyQeGE05N2ac1JF2MRW         2013-10-15  0PRSELwINaU945xsPKJ6mt
# 7Cp8TdTtt8fV9qeefeLsI1         1996-07-15  6qXwLwTLdA44HYsA26vaNU
# 59nmDhy2JsEdeXDCUZlAIk         2002-03-19  5kQGFREO5FzMBMsAO3cEtj
#
#                              artist_name  duration_ms  explicit  \
# song_id
# 6wPA3Eplol740Hftfbu3nY           Toadies     108200.0     False
# 7JwnQlkaGMV2robELlKy9Y          Ministry     181506.0     False
# 1SccyQeGE05N2ac1JF2MRW  David R. Maracle     170906.0     False
# 7Cp8TdTtt8fV9qeefeLsI1             Tonic     212760.0     False
# 59nmDhy2JsEdeXDCUZlAIk    Flogging Molly     125426.0     False
#
#                               linked_album        song_title  danceability  \
# song_id
# ...

# %% [markdown]
# ## Timbre Dimension 10

# %% [markdown]
# **A Mix of Bounce + Net Rhythm?**
#
# Has:
# - Very similar to the "Bounce" (Timbre Dimension 8)
#
# Doesn't Have:
# - Both aggressive rock songs, and instrumental soundtrack music score low on this metric

# %%
main_song_list.sort_values(['tm_dim_10'], axis=0, ascending=False).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 6vN77lE9LK6HP2DewaN6HZ         2018-05-18  5f7VJjfbwm532GiveGC0ZK
# 0Iiig94rtm9br1mx1fRhRV         2018-06-08  1pPmIToKXyGdsCF6LmqLmI
# 6kXBteYQsR9tCoArL8V5mD         2001-07-31  3uISNNuONokIh21KiNharS
# 0o8Ki6DTyYWjleWnDlMUhw         2016-09-09  4BIQA9vRkqXEnA2twmq7mU
# 3TvnVynctZJjAaZjNyIVpS         2018-07-13  15iVAtD3s3FsQR4w1v6M0P
#
#                           artist_name  duration_ms  explicit  \
# song_id
# 6vN77lE9LK6HP2DewaN6HZ       Lil Baby     142273.0      True
# 0Iiig94rtm9br1mx1fRhRV   Rich The Kid     169488.0      True
# 6kXBteYQsR9tCoArL8V5mD  Butch Cassidy     312000.0      True
# 0o8Ki6DTyYWjleWnDlMUhw   Mario Winans     219011.0     False
# 3TvnVynctZJjAaZjNyIVpS     Chief Keef     166855.0      True
#
#                                                  linked_album  \
# song_id
# 6vN77lE9LK6HP2DewaN6HZ                       Harder Than Ever
# ...

# %%
main_song_list.sort_values(['tm_dim_10'], axis=0, ascending=True).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 23ryVoyGTrfO3F0GblIfnz               1986  430byzy0c5bPn5opiu0SRd
# 0cKqpI6pOYeNFK2HPuMHXc         2009-06-09  6AWGppAWm4CeFbR94UnEb0
# 2Wjo03PLbjEzGCAv351lzP         1986-09-16  2hnzQ6eCFkxUIPsVcsdj8A
# 59y8ZGcD7iC5opfJwaTGiH         2018-03-23  4hvwEwrCmGj22uURGVET7Q
# 4A065x9kJt955eGVqf813g         1992-01-01  64tNsm6TnZe2zpcMVMOoHL
#
#                                    artist_name  duration_ms  explicit  \
# song_id
# 23ryVoyGTrfO3F0GblIfnz            Edward Elgar     234133.0     False
# 0cKqpI6pOYeNFK2HPuMHXc           FELIX MEAGHER      95546.0     False
# 2Wjo03PLbjEzGCAv351lzP  The Georgia Satellites     224533.0     False
# 59y8ZGcD7iC5opfJwaTGiH          Monster Magnet     209922.0     False
# 4A065x9kJt955eGVqf813g         Alice In Chains     149466.0     False
#
#                                                              linked_album  \
# song_id
# ...

# %% [markdown]
# ## Timbre Dimension 11

# %% [markdown]
# **Repetitiveness?**
#
# Has:
# - Low instrumentation, repetitive beats
# - Getting songs -w- high speechiness / basically non-songs
#
# Doesn't Have:
# - Much more instrumentation.
# - Most songs seem to build
# - Chords being constantly played in background

# %%
main_song_list.sort_values(['tm_dim_11'], axis=0, ascending=False).head(10)
# Out:
#                        album_release_date               artist_id  \
# song_id
# 2yLkEOhxhUkGnb6V467EmQ               2010  76TM3QXivQvlLmZxdYxMZr
# 6JMIaVMbh5emijDiBODgit               1987  4toEjJSZu1rbfX2hfVdZFA
# 6jK8Eygg279rapL3HvCWoJ               1972  4LjrTfWcvqeHDcH6kr2Msd
# 6kXBteYQsR9tCoArL8V5mD         2001-07-31  3uISNNuONokIh21KiNharS
# 5HK7umkFadON4Z8fverfNZ         2016-02-11  2iHoAyWMSBlE0ynGkTloCn
# 0rRboI6IRuGx56Dq3UdYY4         2001-08-28  4Icvbp9RDt5aY2TWDOVDsr
# 28IvFkxf9TBHdCIe3n1JWm         2001-08-28  4Icvbp9RDt5aY2TWDOVDsr
# 3qnoOm4fwZPBS116f5hpgF         2018-06-01  5K4W6rqBFWDnAN6FQUkS6x
# 1MntHPLU1T7a9W4tojbg8g         1971-01-11  4NgfOZCL9Ml67xzM0xzIvC
# 3Cx9j78Z0NE6jYwBWvvV3P         1992-06-01  0EdvGhlC1FkGItLOWQzG4J
#
#                                     artist_name  duration_ms  explicit  \
# song_id
# 2yLkEOhxhUkGnb6V467EmQ                      666     393070.0     False
# 6JMIaVMbh5emijDiBODgit  Boogie Down Productions     308558.0      True
# ...

# %%
main_song_list.sort_values(['tm_dim_11'], axis=0, ascending=True).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 7hNEzP76pKoToPKofbxU11         2018-06-23  4KZxfeurWrt7s1zsGwY9SW
# 1u1ATklwZesAvq1whHsI8Z         1994-06-06  4P70aqttdpJ9vuYFDmf7f6
# 7JwnQlkaGMV2robELlKy9Y         2009-03-31  1DXylZlWbVvlckNqwvjTEt
# 23ryVoyGTrfO3F0GblIfnz               1986  430byzy0c5bPn5opiu0SRd
# 1t8TgBZYEP3pwwa134Wb5D         1994-11-21  562Od3CffWedyz2BbeYWVn
#
#                                  artist_name  duration_ms  explicit  \
# song_id
# 7hNEzP76pKoToPKofbxU11  Michael J. Mc Donald     230332.0     False
# 1u1ATklwZesAvq1whHsI8Z              Vangelis     279373.0     False
# 7JwnQlkaGMV2robELlKy9Y              Ministry     181506.0     False
# 23ryVoyGTrfO3F0GblIfnz          Edward Elgar     234133.0     False
# 1t8TgBZYEP3pwwa134Wb5D         Mike Oldfield     163693.0     False
#
#                                                              linked_album  \
# song_id
# ...

# %% [markdown]
# ## Timbre Dimension 12

# %% [markdown]
# **Fast n Lite**
#
# Has:
# - Speed, and flutes!
# - Repitition
# - Light sounds? Flutes, bells, etc near or at topline
# - FUGGIN HARPS with the T-Pain song.
#
# Doesn't Have:
# - Some angry singing happening in the first song (1st song)
# - Aggressive, though not necessarily faster than the songs with dim 12 (1st song)
# - Slow
# - Some songs are repititive

# %%
main_song_list.sort_values(['tm_dim_12'], axis=0, ascending=False).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 7GqgXyVdXg443ijRbFLqUf         2014-04-17  1i4xi4ramy5BPYr2Bhf6sc
# 5gsY63Dq5ht0LEvydhj9lA         1986-05-15  3CQIn7N5CuRDP8wEI7FiDA
# 4qg7uptMkSHq8uatbgcP37               1960  7vfydQ0nVBVgJ0ajs8EtRM
# 6PVIF3ZAs38DMjb9WzfbHN         2015-05-04  5tF14orX4tFSqVIm4oA9XD
# 0F7rEdewJ6cSLylOZZpDu7               2005  3aQeKQSyrW4qWr35idm0cy
#
#                                       artist_name  duration_ms  explicit  \
# song_id
# 7GqgXyVdXg443ijRbFLqUf          Montez de Durango     161358.0     False
# 5gsY63Dq5ht0LEvydhj9lA                 Run–D.M.C.     203333.0      True
# 4qg7uptMkSHq8uatbgcP37  Christoph Willibald Gluck     207106.0     False
# 6PVIF3ZAs38DMjb9WzfbHN               WordHarmonic     123733.0     False
# 0F7rEdewJ6cSLylOZZpDu7                     T-Pain     230713.0     False
#
#                                                              linked_album  \
# song_id
# ...

# %%
main_song_list.sort_values(['tm_dim_12'], axis=0, ascending=True).head()
# Out:
#                        album_release_date               artist_id  \
# song_id
# 5RKNHGP5Nv526dJ5LmgcjX         1991-03-20  6JW8wliOEwaDZ231ZY7cf4
# 6wPA3Eplol740Hftfbu3nY         1994-01-01  2QMMktUMtwMSwUZATX1cRO
# 1EcJYWBoOiF8TlcUyYPVY3         2017-07-12  3Eeb1U0VJTDaFpBHV4DmHl
# 6unvI494iEIjwwjElA8IRr         2012-01-01  7I45cJlgpJa5SLVWqocmjb
# 1yJiE307EBIzOB9kqH1deb         1989-04-17  6zvul52xwTWzilBZl6BUbT
#
#                                artist_name  duration_ms  explicit  \
# song_id
# 5RKNHGP5Nv526dJ5LmgcjX           Sepultura     254386.0     False
# 6wPA3Eplol740Hftfbu3nY             Toadies     108200.0     False
# 1EcJYWBoOiF8TlcUyYPVY3  Angelo Badalamenti     271120.0     False
# 6unvI494iEIjwwjElA8IRr         Bill Whelan     101066.0     False
# 1yJiE307EBIzOB9kqH1deb              Pixies     124773.0     False
#
#                                                            linked_album  \
# song_id
# ...
