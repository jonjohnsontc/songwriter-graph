# %% [markdown]
# # Matching Credits to Song Data

# %%
import json
import numpy as np
import pandas as pd
import pickle
import re
from sqlalchemy import *
import time

# %%
with open('../data/genius_song_details_1.json', 'r') as f:
    genius_song_details_1 = json.load(f)

# %%
with open('../data/genius_song_details_2.json', 'r') as f:
    genius_song_details_2 = json.load(f)

# %%
with open('../data/genius_song_details_3.json', 'r') as f:
    genius_song_details_3 = json.load(f)

# %%
with open('../data/genius_song_details_4.json', 'r') as f:
    genius_song_details_4 = json.load(f)

# %%
with open('../data/genius_song_details_5.json', 'r') as f:
    genius_song_details_5 = json.load(f)

# %% [markdown]
# ### What Information do I Want to Model on?
#
# For sure I need `writer_artists`, but beyond that, I don't know.

# %%
# genius_song_details_1[0]['response']['song']['writer_artists']                       #for songwriter info
# genius_song_details_1[0]['response']['song']['writer_artists'][0]['name']            #for writer name
# genius_song_details_1[0]['response']['song']['writer_artists'][0]['id']              #for writer id
# genius_song_details_1[0]['response']['song']['id']                                   #for song id
# genius_song_details_1[0]['response']['song']['title']                                #for song title
# genius_song_details_1[0]['response']['song']['full_title']                           #for full song title
# genius_song_details_1[0]['response']['song']['producer_artists']                     #for credited producer
# genius_song_details_1[0]['response']['song']['primary_artist']                       #for primary artist details
# genius_song_details_1[0]['response']['song']['primary_artist']['name']               #for primary artist name
# genius_song_details_1[0]['response']['song']['primary_artist']['id']                 #for primary artist id
# Out:
# 1

# %% [markdown]
# ### How Many Writers are on a Song?

# %%
def writer_counter(song_details_list):
    count_list = []
    for num, entry in enumerate(song_details_list):
        if isinstance(entry, dict):
            if 'response' in entry.keys():
                count_list.append((len(entry['response']['song']['writer_artists']),  num))
    return max(count_list)

# %%
writer_counter(genius_song_details_4)
# Out:
# (70, 9869)

# %% [markdown]
# A max of 70(!) writers per song is going to give me a lot of columns in this combined table

# %% [markdown]
# ### Tossing Song Details into DataFrame
#
# I'm going to end up creating three separate tables, which will all eventually make their way unto psql:
# - `genius_songwriters` - A DataFrame with every songwriter + songwriter id
# - `genius_song_details` - A DataFrame with a row for every song, inclusive of song title, artist, and requsite id's
# - `genius_song_details_writers` - A DataFrame listing each writer that appears on a given song

# %% [markdown]
# #### Genius Songwriters (Table 1)

# %% [markdown]
# ##### Parsing Songwriters into Separate Lists

# %%
def songwriters_tolist(song_details):
    '''
    Take Genius song details listing, and extract each writer associated with a song id into a new list
    '''
    writer_list = []
    for entry in song_details:
        if isinstance(entry, dict):
            if 'response' in entry.keys():
                g_song_id = entry['response']['song']['id']
                for writer in entry['response']['song']['writer_artists']:
                    writer_list.append({'g_song_id':g_song_id, 'writer_name':writer['name'], 'writer_id':writer['id']})
    return writer_list

# %% [markdown]
# ##### `genius_song_details_1`

# %%
genius_songwriters_1 = songwriters_tolist(genius_song_details_1)

# %%
songwriter_df_1 = pd.DataFrame(genius_songwriters_1)
songwriter_df_1.head()
# Out:
#    g_song_id  writer_id     writer_name
# 0          1      27663  The Heatmakerz
# 1          1          1         Cam’ron
# 2          3       9768       Irv Gotti
# 3          3     644832        H. Davis
# 4          3     214470    B. Bacharach

# %%
songwriter_df_1.shape
# Out:
# (12715, 3)

# %% [markdown]
# ##### `genius_song_details_2`

# %%
genius_songwriters_2 = songwriters_tolist(genius_song_details_2)

# %%
songwriter_df_2 = pd.DataFrame(genius_songwriters_2)
songwriter_df_2.head()
# Out:
#    g_song_id  writer_id  writer_name
# 0       8776      27765  Salaam Remi
# 1       8776         56          Nas
# 2       8776         81           AZ
# 3       8785        998       B-Real
# 4       8874        170       Kurupt

# %% [markdown]
# `genius_song_details_3`

# %%
genius_songwriters_3 = songwriters_tolist(genius_song_details_3)

# %%
songwriter_df_3 = pd.DataFrame(genius_songwriters_3)
songwriter_df_3.head()
# Out:
#    g_song_id  writer_id   writer_name
# 0     149508       9536    Jimmy Page
# 1     149508      12999  Robert Plant
# 2     149625       1080  Walt Whitman
# 3     149629         85          T.I.
# 4     149629        853         B.o.B

# %%
songwriter_df_3.to_csv('../data/genius_songwriters_3.csv')

# %% [markdown]
# `genius_song_details_4`

# %%
genius_songwriters_4 = songwriters_tolist(genius_song_details_4)

# %%
songwriter_df_4 = pd.DataFrame(genius_songwriters_4)
songwriter_df_4.head()
# Out:
#    g_song_id  writer_id writer_name
# 0     436873        660      Prince
# 1     436877        660      Prince
# 2     436879        660      Prince
# 3     436882        660      Prince
# 4     436888        660      Prince

# %%
songwriter_df_4.to_csv('../data/genius_songwriters_4.csv')

# %% [markdown]
# #### Genius Song Details Writers (Table 2)

# %%
songwriter_df_1_2 = pd.read_csv('../data/genius_songwriters_1_2.csv').drop(labels='Unnamed: 0', axis= 1)

# %%
songwriter_df_3 = pd.read_csv('../data/genius_songwriters_3.csv').drop(labels='Unnamed: 0', axis= 1)
songwriter_df_4 = pd.read_csv('../data/genius_songwriters_4.csv').drop(labels='Unnamed: 0', axis= 1)

# %%
songwriter_df_1_2.head(2)
# Out:
#    g_song_id  writer_id     writer_name
# 0          1      27663  The Heatmakerz
# 1          1          1         Cam’ron

# %% [markdown]
# ##### Flattening Songwriter Records

# %%
def flat_songwriter_df(songwriters):
    '''
    Flatten songwriter listing for merge back into song details DataFrame
    '''
    songwriters.set_index('g_song_id', inplace=True)
    songwriters.writer_id = songwriters.writer_id.astype('object')
    songwriters_new = songwriters.drop('writer_name', 1)
    dummies = pd.get_dummies(songwriters_new).reset_index().groupby('g_song_id').sum()
    return dummies

# %%
flat_sw_1_2 = flat_songwriter_df(songwriter_df_1_2)

# %%
flat_sw_3 = flat_songwriter_df(songwriter_df_3)

# %%
flat_sw_4 = flat_songwriter_df(songwriter_df_4)

# %%
flat_sw_1_2.shape
# Out:
# (32550, 12309)

# %% [markdown]
# ##### Merging Flat Songwriter Records

# %%
pd.merge(flat_sw_3, flat_sw_4, how='outer').head()

# %% [markdown]
# #### Concatenating Songwriter Listings & Saving as csv

# %%
songwriter_df = pd.concat([songwriter_df_1, songwriter_df_2])
songwriter_df.reset_index().drop('index', 1, inplace=True)
songwriter_df.to_csv('../data/genius_songwriters_1_2.csv')

# %% [markdown]
# #### Song Details per Song

# %%
def song_details_tolist(song_details):
    '''
    Take Genius song details listing, and extract all important metadata into a new list
    '''
    song_details_list = []
    for entry in song_details:
        if isinstance(entry, dict):
            if 'response' in entry.keys():
                song = entry['response']['song']
                song_details_list.append({'g_song_id':song['id'], 'g_song_title':song['title'], 'g_full_song_title':song['full_title'],
                                          'g_artist_name':song['primary_artist']['name'], 'g_artist_id':song['primary_artist']['id']})
    return song_details_list

# %% [markdown]
# ##### `genius_song_details_1`

# %%
genius_song_details_1_list = song_details_tolist(genius_song_details_1)

# %%
song_details_df_1 = pd.DataFrame(genius_song_details_1_list)
song_details_df_1.set_index('g_song_id', inplace = True)

# %%
# song_details_df_1.head(20)

# %% [markdown]
# ##### `genius_song_details_2`

# %%
genius_song_details_2_list = song_details_tolist(genius_song_details_2)

# %%
song_details_df_2 = pd.DataFrame(genius_song_details_2_list)
song_details_df_2.set_index('g_song_id', inplace = True)

# %% [markdown]
# #### Concatenating Song Detail Listings & Saving as csv

# %%
song_details_df = pd.concat([song_details_df_1, song_details_df_2])
song_details_df.to_csv('../data/genius_song_details_1_2.csv')

# %% [markdown]
# ##### `genius_song_details_3`

# %%
genius_song_details_3_list = song_details_tolist(genius_song_details_3)
song_details_df_3 = pd.DataFrame(genius_song_details_3_list).set_index('g_song_id')
song_details_df_3.shape
# Out:
# (49999, 4)

# %%
song_details_df_3.to_csv('../data/genius_song_details_3.csv')

# %% [markdown]
# ##### `genius_song_details_4`

# %%
genius_song_details_4_list = song_details_tolist(genius_song_details_4)
song_details_df_4 = pd.DataFrame(genius_song_details_4_list).set_index('g_song_id')
song_details_df_4.shape
# Out:
# (49999, 4)

# %%
song_details_df_4.to_csv('../data/genius_song_details_4.csv')

# %% [markdown]
# #### Merging DataFrames

# %% [markdown]
# #### Attempt 1: Writing a Function

# %%
# def writer_check(song_df, writer_list):
#     '''
#     '''
#     for index in song_df.index:
#         count = 0
#         for writer in writer_list:
#             if writer['g_song_id'] == index:
#                 count += 1
#                 song_df['writer_{}_name'.format(count)].loc[index] = writer['writer_name']
#                 song_df['writer_{}_id'.format(count)].loc[index] = writer['writer_id']
#     return song_df

# %% [markdown]
# #### Attempt 2: df merge

# %%
# song_details_df_1.merge(songwriter_df_1, on='g_song_id')

# %% [markdown]
# ## Attempting to Merge

# %% [markdown]
# ### Merging Song Lists
#
# I'm going to first see how merging the `genius_song_list.csv` and `spotify_song_list.csv` goes. My success there will dictate how merging the actual song records goes.

# %% [markdown]
# #### Retrieving Spotify & Genius song lists

# %%
engine = create_engine('postgresql://postgres:glide-mortuary-pod-cloy-belong@ec2-54-244-70-11.us-west-2.compute.amazonaws.com:5432/postgres')
engine.connect()

# %%
spotify_songs = pd.read_sql('SELECT * FROM spotify_song_list', con=engine, index_col='s_song_id')
genius_songs = pd.read_sql('SELECT DISTINCT * FROM genius_song_list', con=engine, index_col='g_song_id')

# %%
genius_songs.shape
# Out:
# (410121, 3)

# %% [markdown]
# #### Creating non-formatted Genius Columns

# %%
strip = lambda x: x.strip("'/*")

# %%
genius_songs['g_artist_n'] = genius_songs['g_artist'].apply(lambda x: str(x).lower()).apply(lambda x: str(x).strip("''/*")) 
genius_songs['g_song_name_n'] = genius_songs['g_song_name'].apply(lambda x: str(x).lower())

# %% [markdown]
# ##### Removing "feat." language in song titles

# %%
genius_songs['g_song_name_n'] = genius_songs['g_song_name_n'].apply(lambda x: re.sub(r'(\(feat.*)','', x))

# %% [markdown]
# ##### Sanity check

# %%
genius_songs[genius_songs['g_song_name_n'] == 'both eyes closed']
# Out:
#                 g_song_name    g_artist  g_artist_id  g_artist_n  \
# g_song_id
# 3099481    Both Eyes Closed  Gucci Mane           13  gucci mane
#
#               g_song_name_n
# g_song_id
# 3099481    both eyes closed

# %% [markdown]
# #### Creating non-formatted Spotify Columns

# %%
spotify_songs['artist_name_n'] = spotify_songs['artist_name'].apply(lambda x: str(x).lower()).apply(lambda x: str(x).strip("''/*")) 
spotify_songs['song_title_n'] = spotify_songs['song_title'].apply(lambda x: str(x).lower())

# %%
spotify_songs['song_title_n'] = spotify_songs['song_title_n'].apply(lambda x: re.sub(r'(\(feat.*)','', x))

# %%
spotify_songs.head()
# Out:
#                        album_release_date               artist_id artist_name  \
# s_song_id
# 62bOmKYxYg7dhrC6gH9vFn         2000-03-21  6Ff53KvcvAj5U7Z1vojB5o      *NSYNC
# 46n2EGFnPC3tzWCN1Aqe26         2000-03-21  6Ff53KvcvAj5U7Z1vojB5o      *NSYNC
# 2AW37v0bDyuOzGP3XnmFuA         2000-03-21  6Ff53KvcvAj5U7Z1vojB5o      *NSYNC
# 594M0rqYMOo8BhMGEdoi5C         1997-05-26  6Ff53KvcvAj5U7Z1vojB5o      *NSYNC
# 0Jc8qF1mUPo1A96HE9QxZz         2001-07-24  6Ff53KvcvAj5U7Z1vojB5o      *NSYNC
#
#                         duration_ms  explicit         linked_album  \
# s_song_id
# 62bOmKYxYg7dhrC6gH9vFn     200400.0     False  No Strings Attached
# 46n2EGFnPC3tzWCN1Aqe26     284760.0     False  No Strings Attached
# 2AW37v0bDyuOzGP3XnmFuA     192426.0     False  No Strings Attached
# 594M0rqYMOo8BhMGEdoi5C     211000.0     False              'N Sync
# 0Jc8qF1mUPo1A96HE9QxZz     238426.0     False            Celebrity
#
#                                               song_title artist_name_n  \
# s_song_id
# 62bOmKYxYg7dhrC6gH9vFn                       Bye Bye Bye         nsync
# 46n2EGFnPC3tzWCN1Aqe26                This I Promise You         nsync
# 2AW37v0bDyuOzGP3XnmFuA                  It's Gonna Be Me         nsync
# 594M0rqYMOo8BhMGEdoi5C  Tearin' up My Heart - Radio Edit         nsync
# 0Jc8qF1mUPo1A96HE9QxZz                               Pop         nsync
#
#                                             song_title_n
# s_song_id
# 62bOmKYxYg7dhrC6gH9vFn                       bye bye bye
# 46n2EGFnPC3tzWCN1Aqe26                this i promise you
# 2AW37v0bDyuOzGP3XnmFuA                  it's gonna be me
# 594M0rqYMOo8BhMGEdoi5C  tearin' up my heart - radio edit
# 0Jc8qF1mUPo1A96HE9QxZz                               pop

# %% [markdown]
# #### Checking my DF's in Excel to see What Other Regex Would be Best

# %%
genius_songs.to_csv('/Users/jonjohnson/Desktop/genius_songs.csv')

# %%
spotify_songs.to_csv('/Users/jonjohnson/Desktop/spotify_songs.csv')

# %% [markdown]
# #### Song List Merge

# %%
genify = pd.merge(spotify_songs, genius_songs, how='left', left_on=['artist_name_n', 'song_title_n'], right_on=['g_artist_n', 'g_song_name_n'])

# %%
genify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23888 entries, 0 to 23887
# Data columns (total 14 columns):
# album_release_date    23888 non-null object
# artist_id             23888 non-null object
# artist_name           23888 non-null object
# duration_ms           23888 non-null float64
# explicit              23888 non-null bool
# linked_album          23888 non-null object
# song_title            23888 non-null object
# artist_name_n         23888 non-null object
# song_title_n          23888 non-null object
# g_song_name           14939 non-null object
# g_artist              14939 non-null object
# g_artist_id           14939 non-null float64
# g_artist_n            14939 non-null object
# g_song_name_n         14939 non-null object
# dtypes: bool(1), float64(2), object(11)
# memory usage: 2.6+ MB

# %%
genify.head(100)
# Out:
#    album_release_date               artist_id          artist_name  \
# 0          2000-03-21  6Ff53KvcvAj5U7Z1vojB5o               *NSYNC
# 1          2000-03-21  6Ff53KvcvAj5U7Z1vojB5o               *NSYNC
# 2          2000-03-21  6Ff53KvcvAj5U7Z1vojB5o               *NSYNC
# 3          1997-05-26  6Ff53KvcvAj5U7Z1vojB5o               *NSYNC
# 4          2001-07-24  6Ff53KvcvAj5U7Z1vojB5o               *NSYNC
# 5          1997-05-26  6Ff53KvcvAj5U7Z1vojB5o               *NSYNC
# 6          2005-10-25  6Ff53KvcvAj5U7Z1vojB5o               *NSYNC
# 7          2005-10-25  6Ff53KvcvAj5U7Z1vojB5o               *NSYNC
# 8          2001-07-24  6Ff53KvcvAj5U7Z1vojB5o               *NSYNC
# 9          2001-07-24  6Ff53KvcvAj5U7Z1vojB5o               *NSYNC
# 10               2006  1bDWGdIC2hardyt55nlQgG  "Weird Al" Yankovic
# 11         1996-12-31  1bDWGdIC2hardyt55nlQgG  "Weird Al" Yankovic
# 12         2017-06-02  1bDWGdIC2hardyt55nlQgG  "Weird Al" Yankovic
# 13         2011-06-17  1bDWGdIC2hardyt55nlQgG  "Weird Al" Yankovic
# 14         2014-07-15  1bDWGdIC2hardyt55nlQgG  "Weird Al" Yankovic
# 15         2018-03-02  1bDWGdIC2hardyt55nlQgG  "Weird Al" Yankovic
# 16         1999-06-29  1bDWGdIC2hardyt55nlQgG  "Weird Al" Yankovic
# 17         2014-07-15  1bDWGdIC2hardyt55nlQgG  "Weird Al" Yankovic
# 18         2014-07-15  1bDWGdIC2hardyt55nlQgG  "Weird Al" Yankovic
# 19         2014-07-15  1bDWGdIC2hardyt55nlQgG  "Weird Al" Yankovic
# 20         2005-01-01  0REMf7H0VP6DwfZ9MbuWph             10 Years
# 21         2017-10-27  0REMf7H0VP6DwfZ9MbuWph             10 Years
# 22         2010-01-01  0REMf7H0VP6DwfZ9MbuWph             10 Years
# 23         2017-10-27  0REMf7H0VP6DwfZ9MbuWph             10 Years
# 24         2008-01-01  0REMf7H0VP6DwfZ9MbuWph             10 Years
# 25         2010-01-01  0REMf7H0VP6DwfZ9MbuWph             10 Years
# 26         2005-01-01  0REMf7H0VP6DwfZ9MbuWph             10 Years
# 27         2008-01-01  0REMf7H0VP6DwfZ9MbuWph             10 Years
# 28         2017-10-27  0REMf7H0VP6DwfZ9MbuWph             10 Years
# 29         2005-01-01  0REMf7H0VP6DwfZ9MbuWph             10 Years
# ..                ...                     ...                  ...
# 70               1996  1ZwdS5xdxEREPySFridCfh                 2Pac
# 71               1996  1ZwdS5xdxEREPySFridCfh                 2Pac
# 72         1998-01-01  1ZwdS5xdxEREPySFridCfh                 2Pac
# 73         1998-01-01  1ZwdS5xdxEREPySFridCfh                 2Pac
# 74               1996  1ZwdS5xdxEREPySFridCfh                 2Pac
# 75         1993-02-16  1ZwdS5xdxEREPySFridCfh                 2Pac
# 76         1995-01-01  1ZwdS5xdxEREPySFridCfh                 2Pac
# 77         2004-01-01  1ZwdS5xdxEREPySFridCfh                 2Pac
# 78         2007-01-01  1ZwdS5xdxEREPySFridCfh                 2Pac
# 79               1996  1ZwdS5xdxEREPySFridCfh                 2Pac
# 80         2014-05-05  18JD8DVlD1fakDAw7E9LFC          2 Unlimited
# 81         2014-05-05  18JD8DVlD1fakDAw7E9LFC          2 Unlimited
# 82         2014-05-05  18JD8DVlD1fakDAw7E9LFC          2 Unlimited
# 83         2014-05-05  18JD8DVlD1fakDAw7E9LFC          2 Unlimited
# 84         2013-11-04  18JD8DVlD1fakDAw7E9LFC          2 Unlimited
# 85         2014-05-05  18JD8DVlD1fakDAw7E9LFC          2 Unlimited
# 86         2014-05-05  18JD8DVlD1fakDAw7E9LFC          2 Unlimited
# 87         2014-05-05  18JD8DVlD1fakDAw7E9LFC          2 Unlimited
# 88         2014-05-05  18JD8DVlD1fakDAw7E9LFC          2 Unlimited
# 89         2014-05-05  18JD8DVlD1fakDAw7E9LFC          2 Unlimited
# 90         2017-09-23  1URnnhqYAYcrqrcwql10ft            21 Savage
# 91         2018-04-06  4kYSro6naA4h99UJvo89HB              Cardi B
# 92         2017-10-30  1URnnhqYAYcrqrcwql10ft            21 Savage
# 93         2016-07-15  1URnnhqYAYcrqrcwql10ft            21 Savage
# 94         2018-05-11  7c0XG5cIJTrrAgEC3ULPiq        Ty Dolla $ign
# 95         2016-07-15  1URnnhqYAYcrqrcwql10ft            21 Savage
# 96         2018-03-23  4TEJudQY2pXxVHPE3gD2EU           BlocBoy JB
# 97         2017-10-30  1URnnhqYAYcrqrcwql10ft            21 Savage
# 98         2017-09-23  1URnnhqYAYcrqrcwql10ft            21 Savage
# 99         2018-02-16  13ubrt8QOOCPljQ2FL1Kca           A$AP Rocky
#
#     duration_ms  explicit                                       linked_album  \
# 0      200400.0     False                                No Strings Attached
# 1      284760.0     False                                No Strings Attached
# 2      192426.0     False                                No Strings Attached
# 3      211000.0     False                                            'N Sync
# 4      238426.0     False                                          Celebrity
# 5      202106.0     False                                            'N Sync
# 6      243493.0     False                                      Greatest Hits
# 7      266293.0     False                                      Greatest Hits
# 8      253600.0     False                                          Celebrity
# 9      292000.0     False                                          Celebrity
# 10     170640.0     False                             Straight Outta Lynwood
# 11     202920.0     False                                       Bad Hair Day
# 12     134373.0     False  Captain Underpants: The First Epic Movie (Orig...
# 13     176800.0     False                                        Alpocalypse
# 14     223120.0     False                                      Mandatory Fun
# 15     300681.0     False                                 The Hamilton Polka
# 16     328773.0     False                              Running With Scissors
# 17     142946.0     False                                      Mandatory Fun
# 18     176306.0     False                                      Mandatory Fun
# 19     173093.0     False                                      Mandatory Fun
# 20     229866.0     False                                  The Autumn Effect
# 21     169520.0     False                            (how to live) AS GHOSTS
# 22     215840.0     False                Feeding The Wolves (Deluxe Version)
# 23     214133.0     False                            (how to live) AS GHOSTS
# 24     195893.0     False                                           Division
# 25     199680.0     False                Feeding The Wolves (Deluxe Version)
# 26     194093.0     False                                  The Autumn Effect
# 27     223613.0     False                                           Division
# 28     211280.0     False                            (how to live) AS GHOSTS
# 29     210013.0     False                                  The Autumn Effect
# ..          ...       ...                                                ...
# 70     278386.0      True                                     All Eyez On Me
# 71     307773.0      True                                     All Eyez On Me
# 72     285026.0     False                                      Greatest Hits
# 73     312626.0      True                                      Greatest Hits
# 74     296906.0      True                                     All Eyez On Me
# 75     259000.0      True                       Strictly 4 My N.I.G.G.A.Z...
# 76     280000.0      True                               Me Against The World
# 77     238053.0      True                                  Loyal To The Game
# 78     268960.0     False                     The Best Of 2Pac (Pt. 1: Thug)
# 79     276813.0      True                                     All Eyez On Me
# 80     223694.0     False                           Unlimited Hits & Remixes
# 81     222668.0     False                           Unlimited Hits & Remixes
# 82     248196.0     False                           Unlimited Hits & Remixes
# 83     218899.0     False                           Unlimited Hits & Remixes
# 84     175115.0     False                                          Get Ready
# 85     219119.0     False                           Unlimited Hits & Remixes
# 86     261274.0     False                           Unlimited Hits & Remixes
# 87     218844.0     False                           Unlimited Hits & Remixes
# 88     206065.0     False                           Unlimited Hits & Remixes
# 89     208021.0     False                           Unlimited Hits & Remixes
# 90     220306.0      True                                         Issa Album
# 91     224284.0      True                                Invasion of Privacy
# 92     268933.0      True                                    Without Warning
# 93     258880.0      True                                        Savage Mode
# 94     200373.0      True                             Beach House 3 (Deluxe)
# 95     235040.0      True                                        Savage Mode
# 96     275872.0      True                        Rover 2.0 (feat. 21 Savage)
# 97     257600.0      True                                    Without Warning
# 98     271306.0      True                                         Issa Album
# 99     232413.0      True                                              Cocky
#
#                                            song_title        artist_name_n  \
# 0                                         Bye Bye Bye                nsync
# 1                                  This I Promise You                nsync
# 2                                    It's Gonna Be Me                nsync
# 3                    Tearin' up My Heart - Radio Edit                nsync
# 4                                                 Pop                nsync
# 5                        I Want You Back - Radio Edit                nsync
# 6   (God Must Have Spent) A Little More Time On Yo...                nsync
# 7                     This I Promise You - Radio Edit                nsync
# 8                                          Girlfriend                nsync
# 9                                                Gone                nsync
# 10  White & Nerdy (Parody of "Ridin'" by Chamillio...  "weird al" yankovic
# 11  Amish Paradise (Parody of "Gangsta's Paradise"...  "weird al" yankovic
# 12                      Captain Underpants Theme Song  "weird al" yankovic
# 13  Party In the CIA (Parody of "Party In The U.S....  "weird al" yankovic
# 14                                        Word Crimes  "weird al" yankovic
# 15                                 The Hamilton Polka  "weird al" yankovic
# 16  The Saga Begins (Lyrical Adaption of "American...  "weird al" yankovic
# 17                                               Foil  "weird al" yankovic
# 18                                              Handy  "weird al" yankovic
# 19                                              Tacky  "weird al" yankovic
# 20                                          Wasteland             10 years
# 21                                          Novacaine             10 years
# 22                                             Fix Me             10 years
# 23                                            Burnout             10 years
# 24                                          Beautiful             10 years
# 25                                       Shoot It Out             10 years
# 26                                          Waking Up             10 years
# 27                                  So Long, Good-bye             10 years
# 28                                      The Messenger             10 years
# 29                                   Through The Iris             10 years
# ..                                                ...                  ...
# 70                               Ambitionz Az A Ridah                 2pac
# 71                                     All Eyez On Me                 2pac
# 72                 California Love - Original Version                 2pac
# 73                        Hit 'Em Up - Single Version                 2pac
# 74                              Only God Can Judge Me                 2pac
# 75                                       I Get Around                 2pac
# 76                                          Dear Mama                 2pac
# 77                                      Ghetto Gospel                 2pac
# 78                    Changes - Greatest Hits Version                 2pac
# 79                                        All About U                 2pac
# 80                                           No Limit          2 unlimited
# 81                       Get Ready - Rap Version Edit          2 unlimited
# 82                                      Twilight Zone          2 unlimited
# 83                                       Tribal Dance          2 unlimited
# 84            Get Ready - Steve Aoki Vocal Radio Edit          2 unlimited
# 85                                     The Real Thing          2 unlimited
# 86                        Get Ready - Steve Aoki Edit          2 unlimited
# 87                     Let the Beat Control Your Body          2 unlimited
# 88                                             No One          2 unlimited
# 89                   Jump For Joy - Yellow Claw Remix          2 unlimited
# 90                                       Bank Account            21 savage
# 91                    Bartier Cardi (feat. 21 Savage)              cardi b
# 92                                  Ghostface Killers            21 savage
# 93                                   X (feat. Future)            21 savage
# 94                            Clout (feat. 21 Savage)        ty dolla $ign
# 95                                           No Heart            21 savage
# 96                                          Rover 2.0           blocboy jb
# 97                                       Rap Saved Me            21 savage
# 98                                               Numb            21 savage
# 99                                              Cocky           a$ap rocky
#
#                                          song_title_n  \
# 0                                         bye bye bye
# 1                                  this i promise you
# 2                                    it's gonna be me
# 3                    tearin' up my heart - radio edit
# 4                                                 pop
# 5                        i want you back - radio edit
# 6   (god must have spent) a little more time on yo...
# 7                     this i promise you - radio edit
# 8                                          girlfriend
# 9                                                gone
# 10  white & nerdy (parody of "ridin'" by chamillio...
# 11  amish paradise (parody of "gangsta's paradise"...
# 12                      captain underpants theme song
# 13  party in the cia (parody of "party in the u.s....
# 14                                        word crimes
# 15                                 the hamilton polka
# 16  the saga begins (lyrical adaption of "american...
# 17                                               foil
# 18                                              handy
# 19                                              tacky
# 20                                          wasteland
# 21                                          novacaine
# 22                                             fix me
# 23                                            burnout
# 24                                          beautiful
# 25                                       shoot it out
# 26                                          waking up
# 27                                  so long, good-bye
# 28                                      the messenger
# 29                                   through the iris
# ..                                                ...
# 70                               ambitionz az a ridah
# 71                                     all eyez on me
# 72                 california love - original version
# 73                        hit 'em up - single version
# 74                              only god can judge me
# 75                                       i get around
# 76                                          dear mama
# 77                                      ghetto gospel
# 78                    changes - greatest hits version
# 79                                        all about u
# 80                                           no limit
# 81                       get ready - rap version edit
# 82                                      twilight zone
# 83                                       tribal dance
# 84            get ready - steve aoki vocal radio edit
# 85                                     the real thing
# 86                        get ready - steve aoki edit
# 87                     let the beat control your body
# 88                                             no one
# 89                   jump for joy - yellow claw remix
# 90                                       bank account
# 91                                     bartier cardi
# 92                                  ghostface killers
# 93                                                 x
# 94                                             clout
# 95                                           no heart
# 96                                          rover 2.0
# 97                                       rap saved me
# 98                                               numb
# 99                                              cocky
#
#                        g_song_name             g_artist  g_artist_id  \
# 0                              NaN                  NaN          NaN
# 1                              NaN                  NaN          NaN
# 2                              NaN                  NaN          NaN
# 3                              NaN                  NaN          NaN
# 4                              NaN                  NaN          NaN
# 5                              NaN                  NaN          NaN
# 6                              NaN                  NaN          NaN
# 7                              NaN                  NaN          NaN
# 8                              NaN                  NaN          NaN
# 9                              NaN                  NaN          NaN
# 10                             NaN                  NaN          NaN
# 11                             NaN                  NaN          NaN
# 12                             NaN                  NaN          NaN
# 13                             NaN                  NaN          NaN
# 14                     Word Crimes  "Weird Al" Yankovic        899.0
# 15              The Hamilton Polka  "Weird Al" Yankovic        899.0
# 16                             NaN                  NaN          NaN
# 17                            Foil  "Weird Al" Yankovic        899.0
# 18                           Handy  "Weird Al" Yankovic        899.0
# 19                           Tacky  "Weird Al" Yankovic        899.0
# 20                       Wasteland             10 Years      89600.0
# 21                       Novacaine             10 Years      89600.0
# 22                          Fix Me             10 Years      89600.0
# 23                         Burnout             10 Years      89600.0
# 24                       Beautiful             10 Years      89600.0
# 25                    Shoot It Out             10 Years      89600.0
# 26                       Waking Up             10 Years      89600.0
# 27                             NaN                  NaN          NaN
# 28                   The Messenger             10 Years      89600.0
# 29                Through The Iris             10 Years      89600.0
# ..                             ...                  ...          ...
# 70            Ambitionz Az a Ridah                 2Pac         59.0
# 71                  All Eyez on Me                 2Pac         59.0
# 72                             NaN                  NaN          NaN
# 73                             NaN                  NaN          NaN
# 74           Only God Can Judge Me                 2Pac         59.0
# 75                    I Get Around                 2Pac         59.0
# 76                       Dear Mama                 2Pac         59.0
# 77                   Ghetto Gospel                 2Pac         59.0
# 78                             NaN                  NaN          NaN
# 79                             NaN                  NaN          NaN
# 80                        No Limit          2 Unlimited     364513.0
# 81    Get Ready - Rap Version Edit          2 Unlimited     364513.0
# 82                   Twilight Zone          2 Unlimited     364513.0
# 83                    Tribal Dance          2 Unlimited     364513.0
# 84                             NaN                  NaN          NaN
# 85                  The Real Thing          2 Unlimited     364513.0
# 86                             NaN                  NaN          NaN
# 87  Let The Beat Control Your Body          2 Unlimited     364513.0
# 88                          No One          2 Unlimited     364513.0
# 89                             NaN                  NaN          NaN
# 90                    Bank Account            21 Savage     430404.0
# 91                             NaN                  NaN          NaN
# 92                             NaN                  NaN          NaN
# 93                             NaN                  NaN          NaN
# 94                             NaN                  NaN          NaN
# 95                             NaN                  NaN          NaN
# 96                       Rover 2.0           BlocBoy JB    1254513.0
# 97                             NaN                  NaN          NaN
# 98                            Numb            21 Savage     430404.0
# 99                             NaN                  NaN          NaN
#
#              g_artist_n                   g_song_name_n
# 0                   NaN                             NaN
# 1                   NaN                             NaN
# 2                   NaN                             NaN
# 3                   NaN                             NaN
# 4                   NaN                             NaN
# 5                   NaN                             NaN
# 6                   NaN                             NaN
# 7                   NaN                             NaN
# 8                   NaN                             NaN
# 9                   NaN                             NaN
# 10                  NaN                             NaN
# 11                  NaN                             NaN
# 12                  NaN                             NaN
# 13                  NaN                             NaN
# 14  "weird al" yankovic                     word crimes
# 15  "weird al" yankovic              the hamilton polka
# 16                  NaN                             NaN
# 17  "weird al" yankovic                            foil
# 18  "weird al" yankovic                           handy
# 19  "weird al" yankovic                           tacky
# 20             10 years                       wasteland
# 21             10 years                       novacaine
# 22             10 years                          fix me
# 23             10 years                         burnout
# 24             10 years                       beautiful
# 25             10 years                    shoot it out
# 26             10 years                       waking up
# 27                  NaN                             NaN
# 28             10 years                   the messenger
# 29             10 years                through the iris
# ..                  ...                             ...
# 70                 2pac            ambitionz az a ridah
# 71                 2pac                  all eyez on me
# 72                  NaN                             NaN
# 73                  NaN                             NaN
# 74                 2pac           only god can judge me
# 75                 2pac                    i get around
# 76                 2pac                       dear mama
# 77                 2pac                   ghetto gospel
# 78                  NaN                             NaN
# 79                  NaN                             NaN
# 80          2 unlimited                        no limit
# 81          2 unlimited    get ready - rap version edit
# 82          2 unlimited                   twilight zone
# 83          2 unlimited                    tribal dance
# 84                  NaN                             NaN
# 85          2 unlimited                  the real thing
# 86                  NaN                             NaN
# 87          2 unlimited  let the beat control your body
# 88          2 unlimited                          no one
# 89                  NaN                             NaN
# 90            21 savage                    bank account
# 91                  NaN                             NaN
# 92                  NaN                             NaN
# 93                  NaN                             NaN
# 94                  NaN                             NaN
# 95                  NaN                             NaN
# 96           blocboy jb                       rover 2.0
# 97                  NaN                             NaN
# 98            21 savage                            numb
# 99                  NaN                             NaN
#
# [100 rows x 14 columns]

# %%
genify.to_csv('/Users/jonjohnson/Desktop/genify.csv')

# %% [markdown]
# A ton of null values here. There should be far more matches.
#
# Strategies for matching:
#  - Pull out non-alphanumeric characters from artist names (+ potentially song names)

# %%
spotify_songs['artist_name'].apply(strip)
# Out:
# s_song_id
# 62bOmKYxYg7dhrC6gH9vFn                  NSYNC
# 46n2EGFnPC3tzWCN1Aqe26                  NSYNC
# 2AW37v0bDyuOzGP3XnmFuA                  NSYNC
# 594M0rqYMOo8BhMGEdoi5C                  NSYNC
# 0Jc8qF1mUPo1A96HE9QxZz                  NSYNC
# 5YTMRAT4yKgFrepF8Hi3mY                  NSYNC
# 72otaqywVqwyXaCjk75JKm                  NSYNC
# 1JbzBbwkf93dii20EC3EiZ                  NSYNC
# 6u5flhVFxKZrl9AApvf2SL                  NSYNC
# 4CCUjYJPbSXLL23BFeBVbI                  NSYNC
# 60R2v9lheAu3lwZwAFxMZK    "Weird Al" Yankovic
# 5r96TaQquRrlo3Ym3ZlSL2    "Weird Al" Yankovic
# 1SGnWl33MUNd9QHYAoqJtW    "Weird Al" Yankovic
# 5eZaT21ZVGyGHJ8kcwaNxA    "Weird Al" Yankovic
# 4JqQWAr47pGEoaMArpA7Z3    "Weird Al" Yankovic
# 1nXCcO9Fp1mE0rzw39qOPY    "Weird Al" Yankovic
# 74sUbOF9Zm8LdGUJjxleTl    "Weird Al" Yankovic
# 0WJTdVboKc2KI1DzzAWyYM    "Weird Al" Yankovic
# 4ZJGobiy4ayWSdKfoqMRlX    "Weird Al" Yankovic
# 1ZqKCseNe8FIZRDyl2E2Ac    "Weird Al" Yankovic
# 3pO37BXsjMC2wApALxGbuB               10 Years
# 0uyDAijTR0tOuH24hxDhE5               10 Years
# 60OKW0mZiPFHVpHl3eHueg               10 Years
# 5vhT2fcFXcRPnJPQA0m1fv               10 Years
# 6AgtIN7FyBd4zJhZI7mrsz               10 Years
# 6TghWaPh1WHJKWXow7iujH               10 Years
# 3eFRjeJ74r4fmo0kXTdi8Y               10 Years
# 5fEyUL1sp1cJC4YErd29I4               10 Years
# 1OA2d84wOUeYfTtuJmO6Zn               10 Years
# 2AMEArFOkOhRxTY3ahlPuc               10 Years
#                                  ...
# 0kz35q6rsNDB6d6XHNfLO4            VeggieTales
# 1zvKLOtOsOgvYJk9yCErRL            VeggieTales
# 7hfoJup1SxCER2qY3hegZ5            VeggieTales
# 1GCULEUkCo5HvEsGvrWuxM            VeggieTales
# 3FQyijPxxQZOD7Q5n9WJiD            VeggieTales
# 2MLvzeplwhyLZwBWkbG9Dx            VeggieTales
# 6u5TlYfQeYthV5Fk8AILLl            VeggieTales
# 1srbr3Qqn2u7dn8W64F2uK            VeggieTales
# 55xnB435duScUVA629QbeH            VeggieTales
# 09tRCU5iG2qIEmAdxgl27f            VeggieTales
# 2Rbq28aQomoEswOXeK27CE         Paul McCartney
# 2AnisDuhsGRXHpuUAqGYsL       Victoria Justice
# 0ytnZPs0sP4pCKNNv21vw1          Ryan McCartan
# 61e03HSUanPGL3M3WSiJgE       Victoria Justice
# 7k52Mhew7PyFnqvlwa9rw3       Victoria Justice
# 3Hl4TSNbfy18evAOoSDHvD      Annaleigh Ashford
# 2lCPing8ljG7emzHmZhdls       Victoria Justice
# 0psnPeWpyAK0pXISBZZey5            Laverne Cox
# 5ROzFLXFHAaWvOZSjJ5Yik          Ryan McCartan
# 2uFfbLiZxTsjSuX3WnvJO4            Laverne Cox
# 1hR3TNe1neCWRQatSVOFfX          Walter Murphy
# 2CG6NC34qho7jtKi5v7FIu          Walter Murphy
# 0twd28NSehiz5u46moeD9N          Walter Murphy
# 3tE2jfKbRj1iwF8Unf1Jhg          Walter Murphy
# 5Jmgv3D2n84tjW1WbQvRUe          Walter Murphy
# 0o2iivelMT3RB0LVP3b1yC          Walter Murphy
# 5MEVYY3YrQIqZJUYkZIRsi          Walter Murphy
# 3pYus3JkGWFh6j30oo0gCv          Walter Murphy
# 3wYQN6dxaRzh9F3sSo7W6a          Walter Murphy
# 5gzm0hBs02qbGUog2iGGWT          Walter Murphy
# Name: artist_name, Length: 23888, dtype: object
