# %% [markdown]
# # Querying ISWC Net Via Splinter to Retreive Songwriter Info

# %%
import splinter
from bs4 import BeautifulSoup

# %%
from splinter import Browser
browse = Browser()
browse.visit('https://iswcnet.cisac.org/logon.do')

# %%
button = browse.find_by_xpath('/html/body/table/tbody/tr/td/table/tbody/tr/td[1]/table/tbody/tr[4]/td/table/tbody/tr[1]/td/span/form[1]/input[3]')

# %%
button.click()

# %%
button_2 = browse.find_by_xpath('/html/body/table/tbody/tr/td/table/tbody/tr/td[1]/table/tbody/tr[4]/td[1]/form/input[2]')

# %%
button_2.click()

# %%
works_dd = browse.find_by_xpath('/html/body/table/tbody/tr[2]/td/span/div/form/table/tbody/tr[1]/td/table/tbody/tr/td[2]/table/tbody/tr[1]/td[2]/select/option[9]')

# %%
works_dd.click()

# %%
title_search = browse.find_by_xpath('//*[@id="firstCriteriaInput"]')

# %%
browse.fill("firstCriteriaInput", 'bye bye bye')

# %%
search = browse.find_by_xpath('//*[@id="submitButton"]')

# %%
search.click()

# %%
bbb = browse.html

# %%
bs = BeautifulSoup(bbb, 'lxml')

# %%
bs.find_all('td', attrs = {'colspan': "2"})
# Out:
# [<td colspan="2" id="menu" width="100%">
#  <link href="/common/css/defaultMenu.css" media="screen" rel="stylesheet" type="text/css"/>
#  <link href="/common/css/menu-ISWCNET.css" rel="stylesheet" type="text/css"/>
#  <script type="text/javascript">
#  <!--
#  function confirmLogout(){
#  	return confirm("Do you really want to logout?");
#  }
#
#  //-->
#  </script>
#  <table class="menu" width="100%">
#  <tbody>
#  <tr>
#  <td class="margin"></td>
#  </tr>
#  <tr>
#  <td class="logo"><img src="/common/images/transparent.gif"/></td>
#  <td>
#  <style>
#  						table.menuItems.level1 {
#  							display: none;
#  						}
#  					</style>
#  <table class="menuItems level1">
#  <tbody>
#  <tr>
#  <td>
#  <table class="menuItem selected" onmouseout="javascript: this.className='menuItem selected'" onmouseover="javascript: this.className='menuItem selected hover'">
#  <tbody>
#  <tr><td class="menuItemTL"><img height="9px" src="/common/images/transparent.gif" width="9px"/></td><td class="menuItem" rowspan="3">
#  <a href="/menuManagement.do?path=0" target="" title="Musical Works Information">ISWC</a>
#  </td><td class="menuItemTR"><img height="9px" src="/common/images/transparent.gif" width="9px"/></td></tr>
#  <tr><td class="menuItemL"></td><td class="menuItemR"></td></tr>
#  <tr><td class="menuItemBL"><img height="9px" src="/common/images/transparent.gif" width="9px"/></td><td class="menuItemBR"><img height="9px" src="/common/images/transparent.gif" width="9px"/></td></tr>
#  </tbody>
#  </table>
#  </td>
#  <td>
#  <div style="width: 50px;"> </div>
#  </td>
#  <td width="100%"></td>
#  <td style="padding-right: 5px;"><a href="#" onclick="javascript:confirmLogout()" title="Logout"><img src="/common/images/icons/logout.gif"/></a></td>
#  </tr>
#  </tbody>
#  </table>
#  <table class="menuItems level2">
#  <tbody>
#  <tr>
#  <td>
#  <table class="menuItem selected" onmouseout="javascript: this.className='menuItem selected'" onmouseover="javascript: this.className='menuItem selected hover'">
#  <tbody>
#  <tr><td class="menuItemTL"><img height="9px" src="/common/images/transparent.gif" width="9px"/></td><td class="menuItem" rowspan="2">
#  <a href="/menuManagement.do?path=0,0" target="" title="Search works">Search works</a>
#  </td><td class="menuItemTR"><img height="9px" src="/common/images/transparent.gif" width="9px"/></td></tr>
#  <tr><td class="menuItemL"></td><td class="menuItemR"></td></tr>
#  </tbody>
#  </table>
#  </td>
#  <td>
#  <table class="menuItem" onmouseout="javascript: this.className='menuItem'" onmouseover="javascript: this.className='menuItem hover'">
#  <tbody>
#  <tr><td class="menuItemTL"><img height="9px" src="/common/images/transparent.gif" width="9px"/></td><td class="menuItem" rowspan="2">
#  <a href="http://www.cisac.org/CisacPortal/consulterDocument.do?id=24080" target="_blank" title="User Guide">User Guide</a>
#  </td><td class="menuItemTR"><img height="9px" src="/common/images/transparent.gif" width="9px"/></td></tr>
#  <tr><td class="menuItemL"></td><td class="menuItemR"></td></tr>
#  </tbody>
#  </table>
#  </td>
#  <td width="100%"></td>
#  <td style="padding-right: 5px;"><a href="/logout.do" onclick="return confirmLogout();" title="Logout"><img src="/common/images/icons/logout.gif"/></a></td>
#  </tr>
#  </tbody>
#  </table>
#  <table class="menuItems level3">
#  <tbody>
#  <tr>
#  <td width="100%"></td>
#  <td class="resize">
#  <img onclick="switchAndKeepDisplayMode('searchSpan')" src="/common/images/icons/resize.gif" title="hide/unhide search form"/>
#  </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>
#  </tr>
#  </tbody>
#  </table></td>,
#  <td colspan="2" id="search"><span id="searchSpan" style="display: block;">
#  <script language="JavaScript" src="/common/scripts/commonLib.js" type="text/javascript"></script>
#  <script type="text/javascript">
#  var defaults = new Array();
#  var firstCriteriaValues = new Array();
#  defaults['firstCriteria'] = new Array();
#  defaults['firstCriteria']['null'] = 'titleFirstCriteria';
#  var firstCriteriaTypeValues = new Array();
#  defaults['firstCriteriaType'] = new Array();
#  firstCriteriaTypeValues['titleFirstCriteria'] = new Array('E', 'B', 'W');
#  defaults['firstCriteriaType']['titleFirstCriteria'] = 'B';
#  firstCriteriaTypeValues['sanitizedFirstCriteria'] = new Array('E', 'B', 'W');
#  defaults['firstCriteriaType']['sanitizedFirstCriteria'] = 'B';
#  firstCriteriaTypeValues['iswcFirstCriteria'] = new Array('E');
#  defaults['firstCriteriaType']['iswcFirstCriteria'] = 'E';
#  firstCriteriaTypeValues['societyWorkCodeFirstCriteria'] = new Array('E');
#  defaults['firstCriteriaType']['societyWorkCodeFirstCriteria'] = 'E';
#  firstCriteriaTypeValues['ipNameIpiFirstCriteria'] = new Array('E', 'B', 'W');
#  defaults['firstCriteriaType']['ipNameIpiFirstCriteria'] = 'B';
#  firstCriteriaTypeValues['ipNameMwiFirstCriteria'] = new Array('E', 'B', 'W');
#  defaults['firstCriteriaType']['ipNameMwiFirstCriteria'] = 'B';
#  firstCriteriaTypeValues['ipNameNumberFirstCriteria'] = new Array('E');
#  defaults['firstCriteriaType']['ipNameNumberFirstCriteria'] = 'E';
#  firstCriteriaTypeValues['performerFirstCriteria'] = new Array('E', 'B', 'W');
#  defaults['firstCriteriaType']['performerFirstCriteria'] = 'B';
#  var secondCriteriaValues = new Array();
#  defaults['secondCriteria'] = new Array();
#  secondCriteriaValues['titleFirstCriteria'] = new Array('choose', 'ipNameNumberSecondCriteria', 'ipNameIpiSecondCriteria', 'ipNameMwiSecondCriteria', 'performerSecondCriteria');
#  defaults['secondCriteria']['titleFirstCriteria'] = 'choose';
#  secondCriteriaValues['sanitizedFirstCriteria'] = new Array('choose', 'ipNameNumberSecondCriteria', 'ipNameIpiSecondCriteria', 'ipNameMwiSecondCriteria', 'performerSecondCriteria');
#  defaults['secondCriteria']['sanitizedFirstCriteria'] = 'choose';
#  secondCriteriaValues['iswcFirstCriteria'] = new Array('choose');
#  defaults['secondCriteria']['iswcFirstCriteria'] = 'choose';
#  secondCriteriaValues['societyWorkCodeFirstCriteria'] = new Array('choose');
#  defaults['secondCriteria']['societyWorkCodeFirstCriteria'] = 'choose';
#  secondCriteriaValues['ipNameIpiFirstCriteria'] = new Array('choose', 'ipNameNumberSecondCriteria', 'ipNameIpiSecondCriteria', 'ipNameMwiSecondCriteria', 'performerSecondCriteria');
#  defaults['secondCriteria']['ipNameIpiFirstCriteria'] = 'choose';
#  secondCriteriaValues['ipNameMwiFirstCriteria'] = new Array('choose', 'ipNameNumberSecondCriteria', 'ipNameIpiSecondCriteria', 'ipNameMwiSecondCriteria', 'performerSecondCriteria');
#  defaults['secondCriteria']['ipNameMwiFirstCriteria'] = 'choose';
#  secondCriteriaValues['ipNameNumberFirstCriteria'] = new Array('choose', 'ipNameNumberSecondCriteria', 'ipNameIpiSecondCriteria', 'ipNameMwiSecondCriteria', 'performerSecondCriteria');
#  defaults['secondCriteria']['ipNameNumberFirstCriteria'] = 'choose';
#  secondCriteriaValues['performerFirstCriteria'] = new Array('choose');
#  defaults['secondCriteria']['performerFirstCriteria'] = 'choose';
#  var secondCriteriaTypeValues = new Array();
#  defaults['secondCriteriaType'] = new Array();
#  secondCriteriaTypeValues['choose'] = new Array('E');
#  defaults['secondCriteriaType']['choose'] = 'E';
#  secondCriteriaTypeValues['ipNameNumberSecondCriteria'] = new Array('E');
#  defaults['secondCriteriaType']['ipNameNumberSecondCriteria'] = 'E';
#  secondCriteriaTypeValues['ipNameIpiSecondCriteria'] = new Array('E', 'B', 'W');
#  defaults['secondCriteriaType']['ipNameIpiSecondCriteria'] = 'B';
#  secondCriteriaTypeValues['ipNameMwiSecondCriteria'] = new Array('E', 'B', 'W');
#  defaults['secondCriteriaType']['ipNameMwiSecondCriteria'] = 'B';
#  secondCriteriaTypeValues['performerSecondCriteria'] = new Array('E', 'B', 'W');
#  defaults['secondCriteriaType']['performerSecondCriteria'] = 'B';
#  var timeOutValues = new Array();
#  defaults['timeOut'] = new Array();
#  defaults['timeOut']['null'] = '15';
#  var rowsPerPageValues = new Array();
#  defaults['rowsPerPage'] = new Array();
#  defaults['rowsPerPage']['null'] = '5';
#
#  </script>
#  <script language="Javascript1.1" type="text/javascript">
#
#  <!-- Begin
#
#       var bCancel = false;
#
#      function validateMwiSearchForm(form) {
#          if (bCancel)
#        return true;
#          else
#   var formValidationResult;
#         formValidationResult = validateRequired(form) && validateMask(form) && validateMaskDependsOnField(form) && validateInteger(form) && validateIntRange(form);
#       return (formValidationResult == 1);
#     }
#
#      function mwiSearchForm_required () {
#       this.a0 = new Array("firstCriteria", "First Criteria is required.", new Function ("varName", "this.mask=/^titleFirstCriteria|sanitizedFirstCriteria|iswcFirstCriteria|societyWorkCodeFirstCriteria|ipNameIpiFirstCriteria|ipNameMwiFirstCriteria|ipNameNumberFirstCriteria|performerFirstCriteria$/;  return this[varName];"));
#       this.a1 = new Array("firstCriteriaInput", "First Criteria Input is required.", new Function ("varName", "this._titleFirstCriteria=/^[^%_]+$/; this.dependsOn='firstCriteria'; this._sanitizedFirstCriteria=/^[^%_]+$/; this._ipNameIpiFirstCriteria=/^[^%_]+$/; this._societyWorkCodeFirstCriteria=/^[A-Za-z\\-0-9\\s]+$/; this._performerFirstCriteria=/^[^%_]+$/; this._ipNameNumberFirstCriteria=/^(\\d{1,11}(\\s)*)+$/; this._ipNameMwiFirstCriteria=/^[^%_]+$/; this._iswcFirstCriteria=/^[Tt]-\\d{3}\\.\\d{3}\\.\\d{3}-\\d{1}$|^[Tt]?\\d{10}$/;  return this[varName];"));
#       this.a2 = new Array("firstCriteriaType", "First Criteria Type is required.", new Function ("varName", "this.mask=/^[EBW]$/;  return this[varName];"));
#       this.a3 = new Array("rowsPerPage", "???en.mwiSearchForm.rowsPerPage??? is required.", new Function ("varName", "this.min='0'; this.max='100';  return this[varName];"));
#       this.a4 = new Array("timeOut", "???en.mwiSearchForm.timeOut??? is required.", new Function ("varName", "this.min='0'; this.max='60';  return this[varName];"));
#      }
#
#      function mwiSearchForm_mask () {
#       this.a0 = new Array("firstCriteria", "First Criteria is invalid.", new Function ("varName", "this.mask=/^titleFirstCriteria|sanitizedFirstCriteria|iswcFirstCriteria|societyWorkCodeFirstCriteria|ipNameIpiFirstCriteria|ipNameMwiFirstCriteria|ipNameNumberFirstCriteria|performerFirstCriteria$/;  return this[varName];"));
#       this.a1 = new Array("firstCriteriaType", "First Criteria Type is invalid.", new Function ("varName", "this.mask=/^[EBW]$/;  return this[varName];"));
#       this.a2 = new Array("secondCriteria", "Second Criteria is invalid.", new Function ("varName", "this.mask=/^choose|ipNameNumberSecondCriteria|ipNameIpiSecondCriteria|ipNameMwiSecondCriteria|performerSecondCriteria$/;  return this[varName];"));
#       this.a3 = new Array("secondCriteriaType", "Second Criteria Type is invalid.", new Function ("varName", "this.mask=/^[EBW]$/;  return this[varName];"));
#      }
#
#      function mwiSearchForm_maskDependsOnField () {
#       this.a0 = new Array("firstCriteriaInput", "First Criteria Input is invalid.", new Function ("varName", "this._false=/.*/; this.dependsOn='doWildCard'; this._true=/(^$)|(^[^?*]{1,3}$|^[^?*]{3}.+$)/; this._=/.*/;  return this[varName];"));
#       this.a1 = new Array("firstCriteriaInput", "First Criteria Input is invalid.", new Function ("varName", "this._titleFirstCriteria=/^[^%_]+$/; this.dependsOn='firstCriteria'; this._sanitizedFirstCriteria=/^[^%_]+$/; this._ipNameIpiFirstCriteria=/^[^%_]+$/; this._societyWorkCodeFirstCriteria=/^[A-Za-z\\-0-9\\s]+$/; this._performerFirstCriteria=/^[^%_]+$/; this._ipNameNumberFirstCriteria=/^(\\d{1,11}(\\s)*)+$/; this._ipNameMwiFirstCriteria=/^[^%_]+$/; this._iswcFirstCriteria=/^[Tt]-\\d{3}\\.\\d{3}\\.\\d{3}-\\d{1}$|^[Tt]?\\d{10}$/;  return this[varName];"));
#       this.a2 = new Array("secondCriteriaInput", "Second Criteria Input is invalid.", new Function ("varName", "this._performerSecondCriteria=/^[^%_]+$/; this.dependsOn='secondCriteria'; this._choose=/.*/; this._ipNameIpiSecondCriteria=/^[^%_]+$/; this._ipNameMwiSecondCriteria=/^[^%_]+$/; this._ipNameNumberSecondCriteria=/^(\\d{1,11}(\\s)*)+$/;  return this[varName];"));
#      }
#
#      function mwiSearchForm_IntegerValidations () {
#       this.a0 = new Array("thirdCriteriaInput", "???en.mwiSearchForm.thirdCriteriaInput??? must be an integer.", new Function ("varName", " return this[varName];"));
#       this.a1 = new Array("rowsPerPage", "???en.mwiSearchForm.rowsPerPage??? must be an integer.", new Function ("varName", "this.min='0'; this.max='100';  return this[varName];"));
#       this.a2 = new Array("timeOut", "???en.mwiSearchForm.timeOut??? must be an integer.", new Function ("varName", "this.min='0'; this.max='60';  return this[varName];"));
#      }
#
#      function mwiSearchForm_intRange () {
#       this.a0 = new Array("rowsPerPage", "???en.mwiSearchForm.rowsPerPage??? is not in the range 0 through 100.", new Function ("varName", "this.min='0'; this.max='100';  return this[varName];"));
#       this.a1 = new Array("timeOut", "???en.mwiSearchForm.timeOut??? is not in the range 0 through 60.", new Function ("varName", "this.min='0'; this.max='60';  return this[varName];"));
#      }
#
#
#  //End -->
#  </script>
#  <script type="text/javascript">
#  function switchAndKeepDisplayMode(id) {
#  switchDisplayMode(id);
#  var style = getElementStyle(id);
#  if (style.display == "none") {
#  ajaxStoreSessionParameter("/storeParameter.do","mwiSearchForm",false);
#    }else {
#  ajaxStoreSessionParameter("/storeParameter.do","mwiSearchForm",true);
#  }
#  }
#  showElement(getElement("searchSpan"));
#  </script>
#  <div id="traditionalSearchForm">
#  <form action="/MWI/search.do" id="mwiSearchForm" method="post" name="mwiSearchForm" onsubmit="return checkSocietiesSelection('traditionalSearchForm') &amp;&amp; validateMwiSearchForm(this) &amp;&amp; setFormDisabled(this, false);">
#  <input name="isFirstRequest" type="hidden" value="true"/>
#  <input name="doMerge" type="hidden" value="true"/>
#  <input name="resultView" type="hidden" value="DEF"/>
#  <input name="doWildCard" type="hidden" value="false"/>
#  <!-- start enhancement -->
#  <table>
#  <tbody><tr>
#  <td><!-- end enhancement -->
#  <table height="100%" style="vertical-align: top; text-align: center">
#  <tbody><tr valign="top">
#  <!-- first column -->
#  <td height="100%">
#  <table height="100%" style="vertical-align: top;">
#  <!-- first line -->
#  <tbody><tr valign="top">
#  <td align="right" class="SeHeaderText" nowrap="nowrap"><label for="firstCriteria"> Search For : </label></td>
#  <td><select class="SeHeaderSelSrch" name="firstCriteria" onchange="firstCriteriaChanged(this, false);"><option selected="selected" value="titleFirstCriteria">Title</option>
#  <option value="iswcFirstCriteria">ISWC</option>
#  <option value="ipNameMwiFirstCriteria">Creator's Name</option>
#  <option value="ipNameNumberFirstCriteria">Creator-Id</option></select></td>
#  <td><select class="SeHeaderSelView" name="firstCriteriaType"><option style="color: menutext;" value="E">Exact</option>
#  <option selected="selected" style="color: menutext;" value="B">Begins</option>
#  <option style="color: menutext;" value="W">Contains</option></select></td>
#  <td class="SeHeaderText" nowrap="nowrap"><label for="firstCriteriaInput"> = </label></td>
#  <td><input class="SeHeaderInputBox" id="firstCriteriaInput" name="firstCriteriaInput" type="text" value="BYE BYE BYE"/></td>
#  </tr>
#  <!-- second  line -->
#  <tr valign="top">
#  <td align="right" class="SeHeaderText" nowrap="nowrap"><label for="secondCriteria">And For :</label></td>
#  <td><select class="SeHeaderSelSrch" name="secondCriteria" onchange="secondCriteriaChanged(this, false);"><option selected="selected" style="color: menutext;" value="choose">Choose</option>
#  <option style="color: menutext;" value="ipNameNumberSecondCriteria">Creator-Id</option>
#  <option style="color: menutext;" value="ipNameMwiSecondCriteria">Creator's Name</option></select></td>
#  <td><select class="SeHeaderSelView" disabled="" name="secondCriteriaType"><option selected="selected" style="color: menutext;" value="E">Exact</option>
#  <option disabled="" style="color: graytext;" value="B">Begins</option>
#  <option disabled="" style="color: graytext;" value="W">Contains</option></select></td>
#  <td align="right" class="SeHeaderText" nowrap="nowrap"><label for="secondCriteriaInput">=</label></td>
#  <td><input class="SeHeaderInputBox" id="secondCriteriaInput" name="secondCriteriaInput" type="text" value=""/></td>
#  </tr>
#  <!-- third line -->
#  <tr valign="top">
#  <td align="right" class="SeHeaderText" colspan="2" nowrap="nowrap"><input name="category" type="hidden" value="DOM"/></td>
#  <input name="thirdCriteriaInput" type="hidden" value=""/>
#  </tr>
#  </tbody></table>
#  </td>
#  <!-- third column -->
#  <td height="100%">
#  <table height="100%">
#  <!-- second  line -->
#  <tbody><tr>
#  <td align="right" class="SeHeaderText" nowrap="nowrap"><label for="rowsPerPage"> Works/page : </label></td>
#  <td><select class="SeHeaderSelView" name="rowsPerPage"><option value="5">5</option>
#  <option value="10">10</option>
#  <option value="15">15</option>
#  <option value="20">20</option>
#  <option value="25">25</option>
#  <option value="30">30</option>
#  <option value="40">40</option>
#  <option value="50">50</option>
#  <option selected="selected" value="100">100</option></select></td>
#  </tr>
#  <!-- third line -->
#  <tr>
#  <td class="SeHeaderText" nowrap="nowrap"><label for="timeOut"> Timeout (sec.) : </label></td>
#  <td><select class="SeHeaderSelView" name="timeOut"><option value="5">Quick</option>
#  <option selected="selected" value="15">Standard</option>
#  <!-- Prevent http time out by setting 55 seconds instead of 60-->
#  <option value="55">Extensive</option></select></td>
#  </tr>
#  </tbody></table>
#  </td>
#  <td height="100%">
#  <table height="100%">
#  <tbody><tr>
#  <td><script type="text/javascript">
#  	                                 document.write('<input type="submit" name="org.apache.struts.taglib.html.CANCEL" value="Reset" onclick="bCancel=true;" id="cancel" class="FormButton" title="Reset">');
#  	                            </script><input class="FormButton" id="cancel" name="org.apache.struts.taglib.html.CANCEL" onclick="bCancel=true;" title="Reset" type="submit" value="Reset"/>
#  <noscript><input class="FormButton" id="submitButton" name="submitButton" type="submit" value="Search"/></noscript>
#  </td>
#  </tr>
#  <tr>
#  <td><script type="text/javascript">
#  								<!--
#                                      document.write('<input type="submit" name="submitButton" value="Search" id="submitButton" class="FormButton" title="Search">');
#  								-->
#  								</script><input class="FormButton" id="submitButton" name="submitButton" title="Search" type="submit" value="Search"/>
#  <noscript><input class="FormButton" id="cancel" name="org.apache.struts.taglib.html.CANCEL" onclick="bCancel=true;" title="Reset" type="submit" value="Reset"/></noscript>
#  </td>
#  </tr>
#  <tr>
#  <td class="SeHeaderText" nowrap="nowrap"></td>
#  </tr>
#  </tbody></table>
#  </td>
#  </tr>
#  </tbody></table>
#  <!-- start enhancement --></td>
#  </tr>
#  <tr>
#  <td>
#  <div></div>
#  </td>
#  </tr>
#  </tbody></table>
#  <!-- end enhancement -->
#  </form>
#  </div>
#  <script type="text/javascript">
#
#  <!--
#
#
#  		$("#criteriaFilterId").val("all");
#
#
#  	function submitForm(param) {
#  	  if (param) {
#  		  $("#firstCriteriaId").val(param);
#  		  $("#firstCriteriaTypeId").val('W');
#  	  }
#  	}
#
#  	function firstCriteriaChanged(firstCriteria, first) {
#  		var value = firstCriteria.value;
#  		debug('firstCriteriaChanged(' + value + ')');
#
#  		var searchForm = firstCriteria.form;
#
#  		// Update first criteria types
#  		var firstCriteriaType = searchForm.firstCriteriaType;
#  		updateList(firstCriteriaType, firstCriteriaTypeValues[value], defaults['firstCriteriaType'][value]);
#  		if (!first) {
#  			defaultList(firstCriteriaType, defaults['firstCriteriaType'][value]);
#  		}
#
#  		// Update second criteria
#  		var secondCriteria = searchForm.secondCriteria;
#  		updateList(secondCriteria, secondCriteriaValues[value], defaults['secondCriteria'][value]);
#  		if (!first) {
#  			defaultList(secondCriteria, defaults['secondCriteria'][value]);
#  		}
#  		secondCriteriaChanged(secondCriteria, first);
#  	}
#
#  	function secondCriteriaChanged(secondCriteria, first) {
#  		var value = secondCriteria.value;
#  		debug('secondCriteriaChanged(' + value + ')');
#
#  		var searchForm = secondCriteria.form;
#
#  		// Update second criteria types
#  		var secondCriteriaType = searchForm.secondCriteriaType;
#  		updateList(secondCriteriaType, secondCriteriaTypeValues[value], defaults['secondCriteriaType'][value]);
#  		if (!first) {
#  			defaultList(secondCriteriaType, defaults['secondCriteriaType'][value]);
#  		}
#
#  		if (value == 'choose') {
#  			secondCriteria.form.secondCriteriaInput.value = '';
#  		}
#  	}
#
#  	firstCriteriaChanged(document.forms['mwiSearchForm'].firstCriteria, true);
#
#  	document.onkeypress = function (e) {
#  		var event = getEvent(e);
#  		var keyCode = getKeyCode(event);
#  		var source = getSource(event);
#  		var form = null;
#
#  		if (keyCode == 13) {
#  			event.cancelBubble = true;
#  			if (event.stopPropagation) event.stopPropagation();
#  				 form = document.forms['mwiSearchForm'];
#  				 if (form && source && validateMwiSearchForm(form)) {
#  						setFormDisabled(form, false);
#  						getElement("submitButton").focus();
#  						form.submit();
#   				 }
#  			return false;
#  		}
#  		return true;
#  	}
#
#  	//when form is submited, the text box must be enabled in order to send their value, even empty, to the server...
#  	//else the server will use the old value of the textbox and cause validation error.
#  	function enableText(form) {
#  		form['secondCriteriaInput'].disabled = false;
#  		form['firstCriteriaInput'].disabled = false;
#  	}
#
#  	// This functions is triggered on category change.
#  	// Function forwards a message to  resetSocietyListTree() function If current page contains one
#  	function onCategoryChange() {
#  		if(typeof resetSocietyListTree == 'function') {
#  			resetSocietyListTree();
#  		}
#  	}
#
#  	function checkSocietiesSelection(mode) {
#  		return true;
#  	}
#  -->
#  </script>
#  <script src="/common/scripts/jquery.bpopup.min.js" type="text/javascript"></script></span></td>,
#  <td align="right" class="SeHeaderText" colspan="2" nowrap="nowrap"><input name="category" type="hidden" value="DOM"/></td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>BRANTLEY JAMES LINCOLN </td>
#  <td>00125559372 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>MORRIS GARY GWYN </td>
#  <td>00239406465 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">GARY MORRIS</td>,
#  <td colspan="2">MORRIS G</td>,
#  <td colspan="2">MORRIS GARY</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>BRANTLEY JAMES LINCOLN </td>
#  <td>00125559372 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>MORRIS GARY GWYN </td>
#  <td>00239406465 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">GARY MORRIS</td>,
#  <td colspan="2">MORRIS G</td>,
#  <td colspan="2">MORRIS GARY</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>HAYAMI KIYOSHI </td>
#  <td>00203148120 </td>
#  <td>
#  <span class="text" title="Composer">C <span class="question" title="Composer"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>HAYAMI KIYOSHI </td>
#  <td>00203148120 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">SAWADA KENJI</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>KAN </td>
#  <td>00167775032 </td>
#  <td>
#  <span class="text" title="Composer">C <span class="question" title="Composer"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>KAN </td>
#  <td>00167775032 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">KAN</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>MASAYAMA YOUKO </td>
#  <td>00423276866 </td>
#  <td>
#  <span class="text" title="Composer">C <span class="question" title="Composer"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>MASAYAMA YOUKO </td>
#  <td>00423276866 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">MASAYAMA YOUKO</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>ADEMI ADELINA </td>
#  <td>00872515229 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">ADELINA</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>ROGALSKY BENJAMIN REID </td>
#  <td>00449656020 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">BEN ROGALSKY</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>AHMAD KHAN ARISH </td>
#  <td>00581579706 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>PEPE MARK </td>
#  <td>00278877297 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">KING KHAN BBQ SHOW</td>,
#  <td colspan="2">KING KHAN THE BBQ SHOW</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>BIRCH CHRISTOPHER S </td>
#  <td>00348763720 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>CHABLAL SHAUN DURAMI </td>
#  <td>00656896776 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>LAUGHTON ALAINE FRANCOISE </td>
#  <td>00406591462 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">ALAINE</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>HANDMAN LOU </td>
#  <td>00013334527 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>HIRSCH WALTER </td>
#  <td>00014171426 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">BUDDY CLARK</td>,
#  <td colspan="2">CHARLIE BARNET &amp; ORCHESTRA</td>,
#  <td colspan="2">POLLY BERGEN</td>,
#  <td colspan="2">STUFF SMITH AMBROSE &amp; HIS ORCHESTRA</td>,
#  <td colspan="2">WALLER F</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>HANDMAN LOU </td>
#  <td>00013334527 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>HIRSCH WALTER </td>
#  <td>00014171426 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">BUDDY CLARK</td>,
#  <td colspan="2">CHARLIE BARNET &amp; ORCHESTRA</td>,
#  <td colspan="2">POLLY BERGEN</td>,
#  <td colspan="2">STUFF SMITH AMBROSE &amp; HIS ORCHESTRA</td>,
#  <td colspan="2">WALLER F</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>SKATTEBU OEYSTEIN </td>
#  <td>00552675336 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">SKAM</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>AALTONEN HENRY OLAVI </td>
#  <td>00069766421 </td>
#  <td>
#  <span class="text" title="Arranger">AR <span class="question" title="Arranger"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>JAERVINEN ALBERT </td>
#  <td>00069737332 </td>
#  <td>
#  <span class="text" title="Arranger">AR <span class="question" title="Arranger"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>AALTONEN HENRY OLAVI </td>
#  <td>00069766421 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>JAERVINEN ALBERT </td>
#  <td>00069737332 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>AALTONEN HENRY OLAVI </td>
#  <td>00069766421 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>JAERVINEN ALBERT </td>
#  <td>00069737332 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>AALTONEN HENRY OLAVI </td>
#  <td>00069766421 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>JAERVINEN ALBERT </td>
#  <td>00069737332 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>AALTONEN HENRY OLAVI </td>
#  <td>00069766421 </td>
#  <td>
#  <span class="text" title="Arranger">AR <span class="question" title="Arranger"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>JAERVINEN ALBERT </td>
#  <td>00069737332 </td>
#  <td>
#  <span class="text" title="Arranger">AR <span class="question" title="Arranger"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>AALTONEN HENRY OLAVI </td>
#  <td>00069766421 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>JAERVINEN ALBERT </td>
#  <td>00069737332 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>ACKERMANN MICHEL </td>
#  <td>00218361775 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>THOMAS PAUL ROBERT </td>
#  <td>00497904008 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">PAUL ROBERT THOMAS AND MICHEL ACKERMANN</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>ACKERMANN MICHEL </td>
#  <td>00218361775 </td>
#  <td>
#  <span class="text" title="Composer">C <span class="question" title="Composer"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>THOMAS PAUL ROBERT </td>
#  <td>00497904008 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>ADAMS ARTHUR LEON III </td>
#  <td>00512629764 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">BLAMMOS</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>ADAMS ARTHUR LEON III </td>
#  <td>00512629764 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>AHLSTROM ERNEST LEONARD </td>
#  <td>00125086296 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>BECK (USA 2) JOE </td>
#  <td>00245461767 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>ALDRIDGE WAYNE WILLIAM </td>
#  <td>00161141413 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>ANDARY YASMINE </td>
#  <td>00787992454 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>ANGELO ARCE </td>
#  <td>00579668082 </td>
#  <td>
#  <span class="text" title="Composer">C <span class="question" title="Composer"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>ARIA </td>
#  <td>00490516452 </td>
#  <td>
#  <span class="text" title="Composer">C <span class="question" title="Composer"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>ARIA </td>
#  <td>00490516452 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">ARIA</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>ARMSTRONG ANDY </td>
#  <td>00161183394 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>ARRIGONI ALDO </td>
#  <td>00198102072 </td>
#  <td>
#  <span class="text" title="Composer">C <span class="question" title="Composer"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>CACCIATORE FRANCESCO </td>
#  <td>00185096544 </td>
#  <td>
#  <span class="text" title="Composer">C <span class="question" title="Composer"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>GALEA IVAN </td>
#  <td>00176493632 </td>
#  <td>
# ...
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>FISHER RICHARD JOSHUA </td>
#  <td>00858639479 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">FISHER JOSH</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>FORTUNY FREDERIC MAURIC </td>
#  <td>00149873133 </td>
#  <td>
#  <span class="text" title="Composer">C <span class="question" title="Composer"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>DA SILVA EMMANUEL JOAO </td>
#  <td>00151116711 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>ONGUENET YSEULT MARIE </td>
#  <td>00764767000 </td>
#  <td>
#  <span class="text" title="Arranger">AR <span class="question" title="Arranger"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">KARAOKE</td>,
#  <td colspan="2">YSEULT</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>FRANCO EDWARD A </td>
#  <td>00588030438 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>KUNHARDT KRISTIN FLAGG </td>
#  <td>00238311585 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">FLAGG KRISTIN</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>FRANK-JACOBI ROBERT </td>
#  <td>00087524647 </td>
#  <td>
#  <span class="text" title="Composer">C <span class="question" title="Composer"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>FRANK-JACOBI ROBERT </td>
#  <td>00087524647 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>GOLDEN KEMAL JASON </td>
#  <td>00438108562 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>GONJAEFF MAIK </td>
#  <td>00267042472 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>GRAHAME DAVID RICHARD </td>
#  <td>00127057097 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">DAVID GRAHAME</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>HARRIS ANTOINE </td>
#  <td>00547317346 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>HINES BRANDON </td>
#  <td>00497312726 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>REINSTEIN JUSTIN ROBERT </td>
#  <td>00507191958 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">HINES BRANDON</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>HEAD MURRAY SEAFIELD ST GEORGE </td>
#  <td>00066422188 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">HEAD MURRAY</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>HIGELIN JACQUES JOSEPH VICTOR </td>
#  <td>00034437594 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">HIGELIN JACQUES</td>,
#  <td colspan="2">JACQUES HIGELIN</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>HINTZEN YAEL JESSICA D </td>
#  <td>00571723055 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>HOSOTSUBO MOTOYOSHI </td>
#  <td>00167329354 </td>
#  <td>
#  <span class="text" title="Composer">C <span class="question" title="Composer"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>HOSOTSUBO MOTOYOSHI </td>
#  <td>00167329354 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">FUKINO TOU</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>HUGHEY CARLYLE </td>
#  <td>00014560119 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>SMITH (US 1) WILLIAM H </td>
#  <td>00029013510 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>INABA KIMIKO </td>
#  <td>00167086452 </td>
#  <td>
#  <span class="text" title="Composer">C <span class="question" title="Composer"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>INABA KIMIKO </td>
#  <td>00167086452 </td>
#  <td>
#  <span class="text" title="Author">A <span class="question" title="Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2">INABA KIMIKO</td>,
#  <td colspan="2">KEN NAOKO</td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>IRVING RONALD NORMAN </td>
#  <td>00036430404 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>LOPEZ MOLES JOSE MANUEL </td>
#  <td>00079142758 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>MCKILLIP LYNDA MARIA </td>
#  <td>00241448092 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>JAFFRES GERARD </td>
#  <td>00042965176 </td>
#  <td>
#  <span class="text" title="Composer">C <span class="question" title="Composer"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>,
#  <td colspan="2">
#  <table width="100%">
#  <thead>
#  <tr>
#  <th width="41%">Creator(s)</th>
#  <th width="11%">
#  <b>
#  <span class="text" title="Name Number of international IPI system">Creator-Id <span class="question" title="Name Number of international IPI system"> </span></span>
#  </b>
#  </th>
#  <th width="5%">Role</th>
#  <td width="43%"> </td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>JAGGER MICK </td>
#  <td>00015036916 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>RICHARDS KEITH </td>
#  <td>00025969846 </td>
#  <td>
#  <span class="text" title="Composer/Author">CA <span class="question" title="Composer/Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td>RINNE JAANA KRISTIINA </td>
#  <td>00142909572 </td>
#  <td>
#  <span class="text" title="Sub-Author">SA <span class="question" title="Sub-Author"> </span></span>
#  					 </td>
#  <td> </td>
#  </tr>
#  <tr>
#  <td colspan="4"> </td>
#  </tr>
#  </tbody>
#  </table>
#  </td>,
#  <td colspan="2" style="padding: 0px; border-top: #999999 1px outset;"> </td>,
#  <td colspan="2" style="border-top: 2px solid black"> </td>]

# %%
# all_tds = browse.find_by_tag('td[class="artists_cell"]')a
